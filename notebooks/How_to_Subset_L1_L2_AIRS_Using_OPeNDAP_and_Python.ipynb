# %% [markdown]
# # How to Subset L1/L2 AIRS Data Using OPeNDAP and Python
#
# ### Authors: Owen Smith, Jennifer Adams, Chris Battisto
# ### Date Authored: 10-15-2025
#
# ### Timing
#
# Exercise: 5 minutes
#
# ### Overview
#
# The retired SUBSET_AIRS_L1L2 service provided dimension based channel
# subsetting, in addition to both individual variable subsetting and
# variable subsetting based on thematic groups.
#
# This notebook demonstrates subsetting operations for all AIRS
# collections using xarray and the curated subsetting groups from
# `ancillary/subset_airs.json`. The groups and variables provided via
# the json file provides 1:1 functionality with what the retired
# SUBSET_AIRS_L1L2 provided.
#
# All subsetting is performed via xarray. For more information on the xarray datatree structure please see [the xarray documentation on hierarchical data](https://docs.xarray.dev/en/latest/user-guide/hierarchical-data.html).
#
# ### Prerequisites
#
# This notebook was written using Python 3.10, and requires:
# - Valid [Earthdata Login credentials](https://urs.earthdata.nasa.gov), and the generation of [Earthdata Prerequisite Files](https://disc.gsfc.nasa.gov/information/howto?title=How%20to%20Generate%20Earthdata%20Prerequisite%20Files) including the <code>.netrc</code> and `.dodsrc` files.
# - [Xarray](https://docs.xarray.dev/en/stable/)
# - [earthaccess](https://earthaccess.readthedocs.io/en/latest/)
#
# #### Optional Anaconda Environment YAML:
#
# This notebook can be run using the ['nasa-gesdisc-opendap' YAML file](https://github.com/nasa/gesdisc-tutorials/tree/main/environments/nasa-gesdisc-opendap.yml) provided in the 'environments' subfolder.
#
# Please follow the instructions [here](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-from-an-environment-yml-file) to install and activate this environment.

# %% [markdown]
# ---

# %% [markdown]
# ## Section 1: Setup
#
# ### 1. Import Required Libraries

# %%
import xarray as xr
import earthaccess
import json
import urllib.request
import os

auth = earthaccess.login()

# %% [markdown]
# ### 2. Load `subset_airs.json`
#
# The `subset_airs.json` file is stored in the `gesdisc-tutorials` repository, and is streamed to the `subset_airs` variable in the current notebook session.
#
# The file contains channel and frequency values, and their associated dimensional indices, to assist with creating our subsets.

# %% [markdown]
# Initialize information for each AIRS subsetting collection

# %%
url = 'https://raw.githubusercontent.com/nasa/gesdisc-tutorials/refs/heads/194-add-subset_airs_l1l2-opendap-notebook/ancillary/subset_airs.json'
with urllib.request.urlopen(url) as response:
    subset_airs = json.load(response)

print(subset_airs)
# Out:
# {'AIRABRAD_005': {'channels': {'1': {'value': 1,
#     'label': 'channel 1, frequency 23.800 ghz'},
#    '2': {'value': 2, 'label': 'channel 2, frequency 31.400 ghz'},
#    '3': {'value': 3, 'label': 'channel 3, frequency 50.300 ghz'},
#    '4': {'value': 4, 'label': 'channel 4, frequency 52.800 ghz'},
#    '5': {'value': 5, 'label': 'channel 5, frequency 53.596 ± 0.115 ghz'},
#    '6': {'value': 6, 'label': 'channel 6, frequency 54.400 ghz'},
#    '7': {'value': 7, 'label': 'channel 7, frequency 54.940 ghz'},
#    '8': {'value': 8, 'label': 'channel 8, frequency 55.500 ghz'},
#    '9': {'value': 9, 'label': 'channel 9, frequency 57.290344 ghz'},
#    '10': {'value': 10, 'label': 'channel 10, frequency 57.290344 ± 0.217 ghz'},
#    '11': {'value': 11,
#     'label': 'channel 11, frequency 57.290344 ± 0.3224 ± 0.048 ghz'},
#    '12': {'value': 12,
#     'label': 'channel 12, frequency 57.290344 ± 0.3224 ± 0.022 ghz'},
#    '13': {'value': 13,
#     'label': 'channel 13, frequency 57.290344 ± 0.3224 ± 0.010 ghz'},
#    '14': {'value': 14,
#     'label': 'channel 14, frequency 57.290344 ± 0.3224 ± 0.0045 ghz'},
#    '15': {'value': 15, 'label': 'channel 15, frequency 89.000 ghz'}}},
#  'AIRHBRAD_005': {'channels': {'2': {'value': 2,
#     'label': 'channel 2, frequency 150.0 ghz'},
#    '3': {'value': 3, 'label': 'channel 3, frequency 183.31 ± 1.0 ghz'},
#    '4': {'value': 4, 'label': 'channel 4, frequency 183.31 ± 3.0 ghz'},
#    '5': {'value': 5, 'label': 'channel 5, frequency 183.31 ± 7.0 ghz'}}},
#  'AIRVBRAD_005': {'channels': {'1': {'value': 1,
#     'label': 'channel 1, wavelength 0.40-0.44 µm'},
#    '2': {'value': 2, 'label': 'channel 2, wavelength 0.58-0.68 µm'},
#    '3': {'value': 3, 'label': 'channel 3, wavelength 0.71-0.92 µm'},
#    '4': {'value': 4, 'label': 'channel 4, wavelength 0.49-0.94 µm'}}},
#  'AIRXBCAL_005': {'Variables': {'amsu_bt': {'value': 'amsu_bt', 'label': ''},
#    'amsu_landFrac': {'value': 'amsu_landFrac', 'label': ''},
#    'amsu_topog': {'value': 'amsu_topog', 'label': ''},
#    'avnsst': {'value': 'avnsst', 'label': ''},
#    'bt1231': {'value': 'bt1231', 'label': ''},
#    'BT_diff_SO2': {'value': 'BT_diff_SO2', 'label': ''},
#    'cx1231': {'value': 'cx1231', 'label': ''},
#    'cx2395': {'value': 'cx2395', 'label': ''},
#    'cx2616': {'value': 'cx2616', 'label': ''},
#    'cxlpn': {'value': 'cxlpn', 'label': ''},
#    'cxq2': {'value': 'cxq2', 'label': ''},
#    'dust_flag': {'value': 'dust_flag', 'label': ''},
#    'footprint': {'value': 'footprint', 'label': ''},
#    'granule_number': {'value': 'granule_number', 'label': ''},
#    'LandFrac': {'value': 'LandFrac', 'label': ''},
#    'lp2395clim': {'value': 'lp2395clim', 'label': ''},
#    'nominal_freq': {'value': 'nominal_freq', 'label': ''},
#    'radiances': {'value': 'radiances',
#     'label': 'radiances (will automatically be included if any channel ranges are selected)'},
#    'reason': {'value': 'reason', 'label': ''},
#    'satheight': {'value': 'satheight', 'label': ''},
#    'satzen': {'value': 'satzen', 'label': ''},
#    'scan': {'value': 'scan', 'label': ''},
#    'scan_node_type': {'value': 'scan_node_type', 'label': ''},
#    'site': {'value': 'site', 'label': ''},
#    'solzen': {'value': 'solzen', 'label': ''},
#    'sst1231r5': {'value': 'sst1231r5', 'label': ''},
#    'sun_glint_distance': {'value': 'sun_glint_distance', 'label': ''},
#    'topog': {'value': 'topog', 'label': ''},
#    'VisMean': {'value': 'VisMean', 'label': ''},
#    'VisStdDev': {'value': 'VisStdDev', 'label': ''}},
#   'Reason Codes (optional; multiple selections may result in an empty subset)': {'ReasonCode 1': {'value': 'ReasonCode 1',
#     'label': 'reason code 1: clear'},
#    'ReasonCode 2': {'value': 'ReasonCode 2',
#     'label': 'reason code 2: special calibration site'},
#    'ReasonCode 4': {'value': 'ReasonCode 4',
#     'label': 'reason code 4: high clouds'},
#    'ReasonCode 8': {'value': 'ReasonCode 8',
#     'label': 'reason code 8: random sample'}},
#   'Channel Ranges for radiances': {'0': {'value': [0, 130],
#     'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'},
#    '1': {'value': [130, 274],
#     'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'},
#    '2': {'value': [274, 441],
#     'label': 'channel range 275-441, frequency range 728.06/cm - 781.88/cm (long-wave surface)'},
#    '3': {'value': [441, 608],
#     'label': 'channel range 442-608, frequency range 789.26/cm - 852.43/cm (long-wave surface)'},
#    '4': {'value': [608, 769],
#     'label': 'channel range 609-769, frequency range 851.49/cm - 903.78/cm (long-wave surface)'},
#    '5': {'value': [769, 936],
#     'label': 'channel range 770-936, frequency range 911.24/cm - 974.29/cm (long-wave surface)'},
#    '6': {'value': [936, 1103],
#     'label': 'channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)'},
#    '7': {'value': [1103, 1262],
#     'label': 'channel range 1104-1262, frequency range 1056.10/cm - 1136.66/cm (long-wave surface, ozone)'},
#    '8': {'value': [1262, 1368],
#     'label': 'channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)'},
#    '9': {'value': [1368, 1462],
#     'label': 'channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)'},
#    '10': {'value': [1462, 1654],
#     'label': 'channel range 1463-1654, frequency range 1338.16/cm - 1443.07/cm (water vapor)'},
#    '11': {'value': [1654, 1760],
#     'label': 'channel range 1655-1760, frequency range 1460.27/cm - 1527.00/cm (water vapor)'},
#    '12': {'value': [1760, 1864],
#     'label': 'channel range 1761-1864, frequency range 1541.10/cm - 1613.86/cm (water vapor)'},
#    '13': {'value': [1864, 2014],
#     'label': 'channel range 1865-2014, frequency range 2181.50/cm - 2325.06/cm (shortwave temperature sounding, co)'},
#    '14': {'value': [2014, 2144],
#     'label': 'channel range 2015-2144, frequency range 2299.80/cm - 2422.85/cm (shortwave temperature sounding)'},
#    '15': {'value': [2144, 2260],
#     'label': 'channel range 2145-2260, frequency range 2446.20/cm - 2569.75/cm (shortwave surface)'},
#    '16': {'value': [2260, 2378],
#     'label': 'channel range 2261-2378, frequency range 2541.90/cm - 2665.24/cm (shortwave surface)'}}},
#  'AIRIBRAD_005': {'channel ranges': {'0': {'value': [0, 130],
#     'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'},
#    '1': {'value': [130, 274],
#     'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'},
#    '2': {'value': [274, 441],
#     'label': 'channel range 275-441, frequency range 728.06/cm - 781.88/cm (long-wave surface)'},
#    '3': {'value': [441, 608],
#     'label': 'channel range 442-608, frequency range 789.26/cm - 852.43/cm (long-wave surface)'},
#    '4': {'value': [608, 769],
#     'label': 'channel range 609-769, frequency range 851.49/cm - 903.78/cm (long-wave surface)'},
#    '5': {'value': [769, 936],
#     'label': 'channel range 770-936, frequency range 911.24/cm - 974.29/cm (long-wave surface)'},
#    '6': {'value': [936, 1103],
#     'label': 'channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)'},
#    '7': {'value': [1103, 1262],
#     'label': 'channel range 1104-1262, frequency range 1056.10/cm - 1136.66/cm (long-wave surface, ozone)'},
#    '8': {'value': [1262, 1368],
#     'label': 'channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)'},
#    '9': {'value': [1368, 1462],
#     'label': 'channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)'},
#    '10': {'value': [1462, 1654],
#     'label': 'channel range 1463-1654, frequency range 1338.16/cm - 1443.07/cm (water vapor)'},
#    '11': {'value': [1654, 1760],
#     'label': 'channel range 1655-1760, frequency range 1460.27/cm - 1527.00/cm (water vapor)'},
#    '12': {'value': [1760, 1864],
#     'label': 'channel range 1761-1864, frequency range 1541.10/cm - 1613.86/cm (water vapor)'},
#    '13': {'value': [1864, 2014],
#     'label': 'channel range 1865-2014, frequency range 2181.50/cm - 2325.06/cm (shortwave temperature sounding, co)'},
#    '14': {'value': [2014, 2144],
#     'label': 'channel range 2015-2144, frequency range 2299.80/cm - 2422.85/cm (shortwave temperature sounding)'},
#    '15': {'value': [2144, 2260],
#     'label': 'channel range 2145-2260, frequency range 2446.20/cm - 2569.75/cm (shortwave surface)'},
#    '16': {'value': [2260, 2378],
#     'label': 'channel range 2261-2378, frequency range 2541.90/cm - 2665.24/cm (shortwave surface)'}}},
#  'AIRH2RET_006': {'Geolocation Fields': {'Latitude': {'value': 'Latitude',
#     'label': ''},
#    'Longitude': {'value': 'Longitude', 'label': ''},
#    'Time': {'value': 'Time', 'label': ''}},
#   'Attributes': {'processing_level': {'value': 'processing_level',
#     'label': ''},
#    'instrument': {'value': 'instrument', 'label': ''},
#    'DayNightFlag': {'value': 'DayNightFlag', 'label': ''},
#    'AutomaticQAFlag': {'value': 'AutomaticQAFlag', 'label': ''},
#    'NumTotalData': {'value': 'NumTotalData', 'label': ''},
#    'NumProcessData': {'value': 'NumProcessData', 'label': ''},
#    'NumSpecialData': {'value': 'NumSpecialData', 'label': ''},
#    'NumBadData': {'value': 'NumBadData', 'label': ''},
#    'NumMissingData': {'value': 'NumMissingData', 'label': ''},
#    'NumLandSurface': {'value': 'NumLandSurface', 'label': ''},
#    'NumOceanSurface': {'value': 'NumOceanSurface', 'label': ''},
#    'node_type': {'value': 'node_type', 'label': ''},
#    'start_year': {'value': 'start_year', 'label': ''},
#    'start_month': {'value': 'start_month', 'label': ''},
#    'start_day': {'value': 'start_day', 'label': ''},
#    'start_hour': {'value': 'start_hour', 'label': ''},
#    'start_minute': {'value': 'start_minute', 'label': ''},
#    'start_sec': {'value': 'start_sec', 'label': ''},
#    'start_orbit': {'value': 'start_orbit', 'label': ''},
#    'end_orbit': {'value': 'end_orbit', 'label': ''},
#    'orbit_path': {'value': 'orbit_path', 'label': ''},
#    'start_orbit_row': {'value': 'start_orbit_row', 'label': ''},
#    'end_orbit_row': {'value': 'end_orbit_row', 'label': ''},
#    'granule_number': {'value': 'granule_number', 'label': ''},
#    'num_scansets': {'value': 'num_scansets', 'label': ''},
#    'num_scanlines': {'value': 'num_scanlines', 'label': ''},
#    'start_Latitude': {'value': 'start_Latitude', 'label': ''},
#    'start_Longitude': {'value': 'start_Longitude', 'label': ''},
#    'start_Time': {'value': 'start_Time', 'label': ''},
#    'end_Latitude': {'value': 'end_Latitude', 'label': ''},
#    'end_Longitude': {'value': 'end_Longitude', 'label': ''},
#    'end_Time': {'value': 'end_Time', 'label': ''},
#    'eq_x_longitude': {'value': 'eq_x_longitude', 'label': ''},
#    'eq_x_tai': {'value': 'eq_x_tai', 'label': ''},
#    'LonGranuleCen': {'value': 'LonGranuleCen', 'label': ''},
#    'LatGranuleCen': {'value': 'LatGranuleCen', 'label': ''},
#    'LocTimeGranuleCen': {'value': 'LocTimeGranuleCen', 'label': ''},
#    'num_fpe': {'value': 'num_fpe', 'label': ''},
#    'orbitgeoqa': {'value': 'orbitgeoqa', 'label': ''},
#    'num_satgeoqa': {'value': 'num_satgeoqa', 'label': ''},
#    'num_glintgeoqa': {'value': 'num_glintgeoqa', 'label': ''},
#    'num_moongeoqa': {'value': 'num_moongeoqa', 'label': ''},
#    'num_ftptgeoqa': {'value': 'num_ftptgeoqa', 'label': ''},
#    'num_zengeoqa': {'value': 'num_zengeoqa', 'label': ''},
#    'num_demgeoqa': {'value': 'num_demgeoqa', 'label': ''},
#    'CO_first_guess': {'value': 'CO_first_guess', 'label': ''},
#    'CH4_first_guess': {'value': 'CH4_first_guess', 'label': ''},
#    'NumSO2FOVs': {'value': 'NumSO2FOVs', 'label': ''}},
#   'Ancillary Per-Granule Data Fields': {'pressStd': {'value': 'pressStd',
#     'label': ''},
#    'pressH2O': {'value': 'pressH2O', 'label': ''},
#    'MWHingeSurfFreqGHz': {'value': 'MWHingeSurfFreqGHz', 'label': ''}},
#   'Ancillary Along-Track Data Fields': {'satheight': {'value': 'satheight',
#     'label': ''},
#    'satroll': {'value': 'satroll', 'label': ''},
#    'satpitch': {'value': 'satpitch', 'label': ''},
#    'satyaw': {'value': 'satyaw', 'label': ''},
#    'glintlat': {'value': 'glintlat', 'label': ''},
#    'glintlon': {'value': 'glintlon', 'label': ''},
#    'nadirTAI': {'value': 'nadirTAI', 'label': ''},
#    'sat_lat': {'value': 'sat_lat', 'label': ''},
#    'sat_lon': {'value': 'sat_lon', 'label': ''},
#    'scan_node_type': {'value': 'scan_node_type', 'label': ''},
#    'satgeoqa': {'value': 'satgeoqa', 'label': ''},
#    'glintgeoqa': {'value': 'glintgeoqa', 'label': ''},
#    'moongeoqa': {'value': 'moongeoqa', 'label': ''}},
#   'Ancillary Full-Swath Geolocation Fields': {'satzen': {'value': 'satzen',
#     'label': ''},
#    'satazi': {'value': 'satazi', 'label': ''},
#    'solzen': {'value': 'solzen', 'label': ''},
#    'solazi': {'value': 'solazi', 'label': ''},
#    'sun_glint_distance': {'value': 'sun_glint_distance', 'label': ''}},
#   'Ancillary Full-Swath Surface Information from Geolocation': {'topog': {'value': 'topog',
#     'label': ''},
#    'topog_err': {'value': 'topog_err', 'label': ''},
#    'landFrac': {'value': 'landFrac', 'label': ''},
#    'landFrac_err': {'value': 'landFrac_err', 'label': ''},
#    'latAIRS': {'value': 'latAIRS', 'label': ''},
#    'lonAIRS': {'value': 'lonAIRS', 'label': ''},
#    'PSurfStd': {'value': 'PSurfStd', 'label': ''},
#    'PSurfStd_QC': {'value': 'PSurfStd_QC', 'label': ''},
#    'nSurfStd': {'value': 'nSurfStd', 'label': ''}},
#   'Quality Indicator Pressure Boundary Variables': {'PBest': {'value': 'PBest',
#     'label': ''},
#    'PGood': {'value': 'PGood', 'label': ''},
#    'nBestStd': {'value': 'nBestStd', 'label': ''},
#    'nGoodStd': {'value': 'nGoodStd', 'label': ''}},
#   'Surface Property Variables': {'TSurfStd': {'value': 'TSurfStd',
#     'label': ''},
#    'TSurfStd_QC': {'value': 'TSurfStd_QC', 'label': ''},
#    'TSurfStdErr': {'value': 'TSurfStdErr', 'label': ''},
#    'numHingeSurf': {'value': 'numHingeSurf', 'label': ''},
#    'freqEmis': {'value': 'freqEmis', 'label': ''},
#    'emisIRStd': {'value': 'emisIRStd', 'label': ''},
#    'emisIRStd_QC': {'value': 'emisIRStd_QC', 'label': ''},
#    'emisIRStdErr': {'value': 'emisIRStdErr', 'label': ''}},
#   'Air Temperature Variables': {'TAirStd': {'value': 'TAirStd', 'label': ''},
#    'TAirStd_QC': {'value': 'TAirStd_QC', 'label': ''},
#    'TAirStdErr': {'value': 'TAirStdErr', 'label': ''},
#    'TSurfAir': {'value': 'TSurfAir', 'label': ''},
#    'TSurfAir_QC': {'value': 'TSurfAir_QC', 'label': ''},
#    'TSurfAirErr': {'value': 'TSurfAirErr', 'label': ''},
#    'Temp_dof': {'value': 'Temp_dof', 'label': ''}},
#   'Water Vapor Saturation Variables Derived from Temperature': {'H2OMMRSat': {'value': 'H2OMMRSat',
#     'label': ''},
#    'H2OMMRSat_QC': {'value': 'H2OMMRSat_QC', 'label': ''},
#    'H2OMMRSatLevStd': {'value': 'H2OMMRSatLevStd', 'label': ''},
#    'H2OMMRSatLevStd_QC': {'value': 'H2OMMRSatLevStd_QC', 'label': ''},
#    'H2OMMRSatSurf': {'value': 'H2OMMRSatSurf', 'label': ''},
#    'H2OMMRSatSurf_QC': {'value': 'H2OMMRSatSurf_QC', 'label': ''},
#    'H2OMMRSat_liquid': {'value': 'H2OMMRSat_liquid', 'label': ''},
#    'H2OMMRSat_liquid_QC': {'value': 'H2OMMRSat_liquid_QC', 'label': ''},
#    'H2OMMRSatLevStd_liquid': {'value': 'H2OMMRSatLevStd_liquid', 'label': ''},
#    'H2OMMRSatLevStd_liquid_QC': {'value': 'H2OMMRSatLevStd_liquid_QC',
#     'label': ''},
#    'H2OMMRSatSurf_liquid': {'value': 'H2OMMRSatSurf_liquid', 'label': ''},
#    'H2OMMRSatSurf_liquid_QC': {'value': 'H2OMMRSatSurf_liquid_QC',
#     'label': ''}},
#   'Tropopause Variables Derived from Temperature': {'PTropopause': {'value': 'PTropopause',
#     'label': ''},
#    'PTropopause_QC': {'value': 'PTropopause_QC', 'label': ''},
#    'T_Tropopause': {'value': 'T_Tropopause', 'label': ''},
#    'T_Tropopause_QC': {'value': 'T_Tropopause_QC', 'label': ''}},
#   'Water Vapor Variables': {'totH2OStd': {'value': 'totH2OStd', 'label': ''},
#    'totH2OStd_QC': {'value': 'totH2OStd_QC', 'label': ''},
#    'totH2OStdErr': {'value': 'totH2OStdErr', 'label': ''},
#    'H2OMMRStd': {'value': 'H2OMMRStd', 'label': ''},
#    'H2OMMRStd_QC': {'value': 'H2OMMRStd_QC', 'label': ''},
#    'H2OMMRStdErr': {'value': 'H2OMMRStdErr', 'label': ''},
#    'H2OMMRLevStd': {'value': 'H2OMMRLevStd', 'label': ''},
#    'H2OMMRLevStd_QC': {'value': 'H2OMMRLevStd_QC', 'label': ''},
#    'H2OMMRLevStdErr': {'value': 'H2OMMRLevStdErr', 'label': ''},
#    'H2OMMRSurf': {'value': 'H2OMMRSurf', 'label': ''},
#    'H2OMMRSurf_QC': {'value': 'H2OMMRSurf_QC', 'label': ''},
#    'H2OMMRSurfErr': {'value': 'H2OMMRSurfErr', 'label': ''},
#    'num_H2O_Func': {'value': 'num_H2O_Func', 'label': ''},
#    'H2O_verticality': {'value': 'H2O_verticality', 'label': ''},
#    'H2O_dof': {'value': 'H2O_dof', 'label': ''}},
#   'Relative Humidity and Geopotential Height Variables from Temperature and Water Vapor': {'RelHum': {'value': 'RelHum',
#     'label': ''},
#    'RelHum_QC': {'value': 'RelHum_QC', 'label': ''},
#    'RelHumSurf': {'value': 'RelHumSurf', 'label': ''},
#    'RelHumSurf_QC': {'value': 'RelHumSurf_QC', 'label': ''},
#    'RelHum_liquid': {'value': 'RelHum_liquid', 'label': ''},
#    'RelHum_liquid_QC': {'value': 'RelHum_liquid_QC', 'label': ''},
#    'RelHumSurf_liquid': {'value': 'RelHumSurf_liquid', 'label': ''},
#    'RelHumSurf_liquid_QC': {'value': 'RelHumSurf_liquid_QC', 'label': ''},
#    'GP_Tropopause': {'value': 'GP_Tropopause', 'label': ''},
#    'GP_Tropopause_QC': {'value': 'GP_Tropopause_QC', 'label': ''},
#    'GP_Height': {'value': 'GP_Height', 'label': ''},
#    'GP_Height_QC': {'value': 'GP_Height_QC', 'label': ''},
#    'GP_Surface': {'value': 'GP_Surface', 'label': ''},
#    'GP_Surface_QC': {'value': 'GP_Surface_QC', 'label': ''}},
#   'Cloud Formation Variables on 3 by 3 AIRS Fields of View': {'CldFrcTot': {'value': 'CldFrcTot',
#     'label': ''},
#    'CldFrcTot_QC': {'value': 'CldFrcTot_QC', 'label': ''},
#    'CldFrcStd': {'value': 'CldFrcStd', 'label': ''},
#    'CldFrcStd_QC': {'value': 'CldFrcStd_QC', 'label': ''},
#    'CldFrcStdErr': {'value': 'CldFrcStdErr', 'label': ''},
#    'PCldTop': {'value': 'PCldTop', 'label': ''},
#    'PCldTop_QC': {'value': 'PCldTop_QC', 'label': ''},
#    'PCldTopErr': {'value': 'PCldTopErr', 'label': ''},
#    'TCldTop': {'value': 'TCldTop', 'label': ''},
#    'TCldTop_QC': {'value': 'TCldTop_QC', 'label': ''},
#    'TCldTopErr': {'value': 'TCldTopErr', 'label': ''},
#    'nCld': {'value': 'nCld', 'label': ''}},
#   'Ozone Variables': {'totO3Std': {'value': 'totO3Std', 'label': ''},
#    'totO3Std_QC': {'value': 'totO3Std_QC', 'label': ''},
#    'totO3StdErr': {'value': 'totO3StdErr', 'label': ''},
#    'O3VMRStd': {'value': 'O3VMRStd', 'label': ''},
#    'O3VMRStd_QC': {'value': 'O3VMRStd_QC', 'label': ''},
#    'O3VMRStdErr': {'value': 'O3VMRStdErr', 'label': ''},
#    'O3VMRLevStd': {'value': 'O3VMRLevStd', 'label': ''},
#    'O3VMRLevStd_QC': {'value': 'O3VMRLevStd_QC', 'label': ''},
#    'O3VMRLevStdErr': {'value': 'O3VMRLevStdErr', 'label': ''},
#    'num_O3_Func': {'value': 'num_O3_Func', 'label': ''},
#    'O3_verticality': {'value': 'O3_verticality', 'label': ''},
#    'O3_dof': {'value': 'O3_dof', 'label': ''}},
#   'Carbon Monoxide Variables': {'COVMRLevStd': {'value': 'COVMRLevStd',
#     'label': ''},
#    'COVMRLevStd_QC': {'value': 'COVMRLevStd_QC', 'label': ''},
#    'COVMRLevStdErr': {'value': 'COVMRLevStdErr', 'label': ''},
#    'num_CO_Func': {'value': 'num_CO_Func', 'label': ''},
#    'CO_verticality': {'value': 'CO_verticality', 'label': ''},
#    'CO_dof': {'value': 'CO_dof', 'label': ''}},
#   'Methane Variables': {'CH4VMRLevStd': {'value': 'CH4VMRLevStd', 'label': ''},
#    'CH4VMRLevStd_QC': {'value': 'CH4VMRLevStd_QC', 'label': ''},
#    'CH4VMRLevStdErr': {'value': 'CH4VMRLevStdErr', 'label': ''},
#    'num_CH4_Func': {'value': 'num_CH4_Func', 'label': ''},
#    'CH4_verticality_10func': {'value': 'CH4_verticality_10func', 'label': ''},
#    'CH4_dof': {'value': 'CH4_dof', 'label': ''}},
#   'Outgoing Longwave Radiation Variables': {'olr': {'value': 'olr',
#     'label': ''},
#    'olr_QC': {'value': 'olr_QC', 'label': ''},
#    'olr3x3': {'value': 'olr3x3', 'label': ''},
#    'olr3x3_QC': {'value': 'olr3x3_QC', 'label': ''},
#    'olr_err': {'value': 'olr_err', 'label': ''},
#    'clrolr': {'value': 'clrolr', 'label': ''},
#    'clrolr_QC': {'value': 'clrolr_QC', 'label': ''},
#    'clrolr_err': {'value': 'clrolr_err', 'label': ''}},
#   'Geolocation QA Variables': {'ftptgeoqa': {'value': 'ftptgeoqa',
#     'label': ''},
#    'zengeoqa': {'value': 'zengeoqa', 'label': ''},
#    'demgeoqa': {'value': 'demgeoqa', 'label': ''}},
#   'Miscellaneous Variables': {'dust_flag': {'value': 'dust_flag', 'label': ''},
#    'all_spots_avg': {'value': 'all_spots_avg', 'label': ''},
#    'retrieval_type': {'value': 'retrieval_type', 'label': ''},
#    'SurfClass': {'value': 'SurfClass', 'label': ''}},
#   'Microwave Dependent Variables': {'TAirMWOnlyStd': {'value': 'TAirMWOnlyStd',
#     'label': ''},
#    'TAirMWOnlyStd_QC': {'value': 'TAirMWOnlyStd_QC', 'label': ''},
#    'MWSurfClass': {'value': 'MWSurfClass', 'label': ''},
#    'sfcTbMWStd': {'value': 'sfcTbMWStd', 'label': ''},
#    'sfcTbMWStd_QC': {'value': 'sfcTbMWStd_QC', 'label': ''},
#    'EmisMWStd': {'value': 'EmisMWStd', 'label': ''},
#    'EmisMWStd_QC': {'value': 'EmisMWStd_QC', 'label': ''},
#    'EmisMWStdErr': {'value': 'EmisMWStdErr', 'label': ''},
#    'totH2OMWOnlyStd': {'value': 'totH2OMWOnlyStd', 'label': ''},
#    'totH2OMWOnlyStd_QC': {'value': 'totH2OMWOnlyStd_QC', 'label': ''},
#    'GP_Height_MWOnly': {'value': 'GP_Height_MWOnly', 'label': ''},
#    'GP_Height_MWOnly_QC': {'value': 'GP_Height_MWOnly_QC', 'label': ''},
#    'MW_ret_used': {'value': 'MW_ret_used', 'label': ''},
#    'totCldH2OStd': {'value': 'totCldH2OStd', 'label': ''},
#    'totCldH2OStd_QC': {'value': 'totCldH2OStd_QC', 'label': ''},
#    'totCldH2OStdErr': {'value': 'totCldH2OStdErr', 'label': ''}}},
#  'AIRS2RET_006': {'Geolocation Fields': {'Latitude': {'value': 'Latitude',
#     'label': ''},
#    'Longitude': {'value': 'Longitude', 'label': ''},
#    'Time': {'value': 'Time', 'label': ''}},
#   'Attributes': {'processing_level': {'value': 'processing_level',
#     'label': ''},
#    'instrument': {'value': 'instrument', 'label': ''},
#    'DayNightFlag': {'value': 'DayNightFlag', 'label': ''},
#    'AutomaticQAFlag': {'value': 'AutomaticQAFlag', 'label': ''},
#    'NumTotalData': {'value': 'NumTotalData', 'label': ''},
#    'NumProcessData': {'value': 'NumProcessData', 'label': ''},
#    'NumSpecialData': {'value': 'NumSpecialData', 'label': ''},
#    'NumBadData': {'value': 'NumBadData', 'label': ''},
#    'NumMissingData': {'value': 'NumMissingData', 'label': ''},
#    'NumLandSurface': {'value': 'NumLandSurface', 'label': ''},
#    'NumOceanSurface': {'value': 'NumOceanSurface', 'label': ''},
#    'node_type': {'value': 'node_type', 'label': ''},
#    'start_year': {'value': 'start_year', 'label': ''},
#    'start_month': {'value': 'start_month', 'label': ''},
#    'start_day': {'value': 'start_day', 'label': ''},
#    'start_hour': {'value': 'start_hour', 'label': ''},
#    'start_minute': {'value': 'start_minute', 'label': ''},
#    'start_sec': {'value': 'start_sec', 'label': ''},
#    'start_orbit': {'value': 'start_orbit', 'label': ''},
#    'end_orbit': {'value': 'end_orbit', 'label': ''},
#    'orbit_path': {'value': 'orbit_path', 'label': ''},
#    'start_orbit_row': {'value': 'start_orbit_row', 'label': ''},
#    'end_orbit_row': {'value': 'end_orbit_row', 'label': ''},
#    'granule_number': {'value': 'granule_number', 'label': ''},
#    'num_scansets': {'value': 'num_scansets', 'label': ''},
#    'num_scanlines': {'value': 'num_scanlines', 'label': ''},
#    'start_Latitude': {'value': 'start_Latitude', 'label': ''},
#    'start_Longitude': {'value': 'start_Longitude', 'label': ''},
#    'start_Time': {'value': 'start_Time', 'label': ''},
#    'end_Latitude': {'value': 'end_Latitude', 'label': ''},
#    'end_Longitude': {'value': 'end_Longitude', 'label': ''},
#    'end_Time': {'value': 'end_Time', 'label': ''},
#    'eq_x_longitude': {'value': 'eq_x_longitude', 'label': ''},
#    'eq_x_tai': {'value': 'eq_x_tai', 'label': ''},
#    'LonGranuleCen': {'value': 'LonGranuleCen', 'label': ''},
#    'LatGranuleCen': {'value': 'LatGranuleCen', 'label': ''},
#    'LocTimeGranuleCen': {'value': 'LocTimeGranuleCen', 'label': ''},
#    'num_fpe': {'value': 'num_fpe', 'label': ''},
#    'orbitgeoqa': {'value': 'orbitgeoqa', 'label': ''},
#    'num_satgeoqa': {'value': 'num_satgeoqa', 'label': ''},
#    'num_glintgeoqa': {'value': 'num_glintgeoqa', 'label': ''},
#    'num_moongeoqa': {'value': 'num_moongeoqa', 'label': ''},
#    'num_ftptgeoqa': {'value': 'num_ftptgeoqa', 'label': ''},
#    'num_zengeoqa': {'value': 'num_zengeoqa', 'label': ''},
#    'num_demgeoqa': {'value': 'num_demgeoqa', 'label': ''},
#    'CO_first_guess': {'value': 'CO_first_guess', 'label': ''},
#    'CH4_first_guess': {'value': 'CH4_first_guess', 'label': ''},
#    'NumSO2FOVs': {'value': 'NumSO2FOVs', 'label': ''}},
#   'Ancillary Per-Granule Data Fields': {'pressStd': {'value': 'pressStd',
#     'label': ''},
#    'pressH2O': {'value': 'pressH2O', 'label': ''},
#    'MWHingeSurfFreqGHz': {'value': 'MWHingeSurfFreqGHz', 'label': ''}},
#   'Ancillary Along-Track Data Fields': {'satheight': {'value': 'satheight',
#     'label': ''},
#    'satroll': {'value': 'satroll', 'label': ''},
#    'satpitch': {'value': 'satpitch', 'label': ''},
#    'satyaw': {'value': 'satyaw', 'label': ''},
#    'glintlat': {'value': 'glintlat', 'label': ''},
#    'glintlon': {'value': 'glintlon', 'label': ''},
#    'nadirTAI': {'value': 'nadirTAI', 'label': ''},
#    'sat_lat': {'value': 'sat_lat', 'label': ''},
#    'sat_lon': {'value': 'sat_lon', 'label': ''},
#    'scan_node_type': {'value': 'scan_node_type', 'label': ''},
#    'satgeoqa': {'value': 'satgeoqa', 'label': ''},
#    'glintgeoqa': {'value': 'glintgeoqa', 'label': ''},
#    'moongeoqa': {'value': 'moongeoqa', 'label': ''}},
#   'Ancillary Full-Swath Geolocation Fields': {'satzen': {'value': 'satzen',
#     'label': ''},
#    'satazi': {'value': 'satazi', 'label': ''},
#    'solzen': {'value': 'solzen', 'label': ''},
#    'solazi': {'value': 'solazi', 'label': ''},
#    'sun_glint_distance': {'value': 'sun_glint_distance', 'label': ''}},
#   'Ancillary Full-Swath Surface Information from Geolocation': {'topog': {'value': 'topog',
#     'label': ''},
#    'topog_err': {'value': 'topog_err', 'label': ''},
#    'landFrac': {'value': 'landFrac', 'label': ''},
#    'landFrac_err': {'value': 'landFrac_err', 'label': ''},
#    'latAIRS': {'value': 'latAIRS', 'label': ''},
#    'lonAIRS': {'value': 'lonAIRS', 'label': ''},
#    'PSurfStd': {'value': 'PSurfStd', 'label': ''},
#    'PSurfStd_QC': {'value': 'PSurfStd_QC', 'label': ''},
#    'nSurfStd': {'value': 'nSurfStd', 'label': ''}},
#   'Quality Indicator Pressure Boundary Variables': {'PBest': {'value': 'PBest',
#     'label': ''},
#    'PGood': {'value': 'PGood', 'label': ''},
#    'nBestStd': {'value': 'nBestStd', 'label': ''},
#    'nGoodStd': {'value': 'nGoodStd', 'label': ''}},
#   'Surface Property Variables': {'TSurfStd': {'value': 'TSurfStd',
#     'label': ''},
#    'TSurfStd_QC': {'value': 'TSurfStd_QC', 'label': ''},
#    'TSurfStdErr': {'value': 'TSurfStdErr', 'label': ''},
#    'numHingeSurf': {'value': 'numHingeSurf', 'label': ''},
#    'freqEmis': {'value': 'freqEmis', 'label': ''},
#    'emisIRStd': {'value': 'emisIRStd', 'label': ''},
#    'emisIRStd_QC': {'value': 'emisIRStd_QC', 'label': ''},
#    'emisIRStdErr': {'value': 'emisIRStdErr', 'label': ''}},
#   'Air Temperature Variables': {'TAirStd': {'value': 'TAirStd', 'label': ''},
#    'TAirStd_QC': {'value': 'TAirStd_QC', 'label': ''},
#    'TAirStdErr': {'value': 'TAirStdErr', 'label': ''},
#    'TSurfAir': {'value': 'TSurfAir', 'label': ''},
#    'TSurfAir_QC': {'value': 'TSurfAir_QC', 'label': ''},
#    'TSurfAirErr': {'value': 'TSurfAirErr', 'label': ''},
#    'Temp_dof': {'value': 'Temp_dof', 'label': ''}},
#   'Water Vapor Saturation Variables Derived from Temperature': {'H2OMMRSat': {'value': 'H2OMMRSat',
#     'label': ''},
#    'H2OMMRSat_QC': {'value': 'H2OMMRSat_QC', 'label': ''},
#    'H2OMMRSatLevStd': {'value': 'H2OMMRSatLevStd', 'label': ''},
#    'H2OMMRSatLevStd_QC': {'value': 'H2OMMRSatLevStd_QC', 'label': ''},
#    'H2OMMRSatSurf': {'value': 'H2OMMRSatSurf', 'label': ''},
#    'H2OMMRSatSurf_QC': {'value': 'H2OMMRSatSurf_QC', 'label': ''},
#    'H2OMMRSat_liquid': {'value': 'H2OMMRSat_liquid', 'label': ''},
#    'H2OMMRSat_liquid_QC': {'value': 'H2OMMRSat_liquid_QC', 'label': ''},
#    'H2OMMRSatLevStd_liquid': {'value': 'H2OMMRSatLevStd_liquid', 'label': ''},
#    'H2OMMRSatLevStd_liquid_QC': {'value': 'H2OMMRSatLevStd_liquid_QC',
#     'label': ''},
#    'H2OMMRSatSurf_liquid': {'value': 'H2OMMRSatSurf_liquid', 'label': ''},
#    'H2OMMRSatSurf_liquid_QC': {'value': 'H2OMMRSatSurf_liquid_QC',
#     'label': ''}},
#   'Tropopause Variables Derived from Temperature': {'PTropopause': {'value': 'PTropopause',
#     'label': ''},
#    'PTropopause_QC': {'value': 'PTropopause_QC', 'label': ''},
#    'T_Tropopause': {'value': 'T_Tropopause', 'label': ''},
#    'T_Tropopause_QC': {'value': 'T_Tropopause_QC', 'label': ''}},
#   'Water Vapor Variables': {'totH2OStd': {'value': 'totH2OStd', 'label': ''},
#    'totH2OStd_QC': {'value': 'totH2OStd_QC', 'label': ''},
#    'totH2OStdErr': {'value': 'totH2OStdErr', 'label': ''},
#    'H2OMMRStd': {'value': 'H2OMMRStd', 'label': ''},
#    'H2OMMRStd_QC': {'value': 'H2OMMRStd_QC', 'label': ''},
#    'H2OMMRStdErr': {'value': 'H2OMMRStdErr', 'label': ''},
#    'H2OMMRLevStd': {'value': 'H2OMMRLevStd', 'label': ''},
#    'H2OMMRLevStd_QC': {'value': 'H2OMMRLevStd_QC', 'label': ''},
#    'H2OMMRLevStdErr': {'value': 'H2OMMRLevStdErr', 'label': ''},
#    'H2OMMRSurf': {'value': 'H2OMMRSurf', 'label': ''},
#    'H2OMMRSurf_QC': {'value': 'H2OMMRSurf_QC', 'label': ''},
#    'H2OMMRSurfErr': {'value': 'H2OMMRSurfErr', 'label': ''},
#    'num_H2O_Func': {'value': 'num_H2O_Func', 'label': ''},
#    'H2O_verticality': {'value': 'H2O_verticality', 'label': ''},
#    'H2O_dof': {'value': 'H2O_dof', 'label': ''}},
#   'Relative Humidity and Geopotential Height Variables from Temperature and Water Vapor': {'RelHum': {'value': 'RelHum',
#     'label': ''},
#    'RelHum_QC': {'value': 'RelHum_QC', 'label': ''},
#    'RelHumSurf': {'value': 'RelHumSurf', 'label': ''},
#    'RelHumSurf_QC': {'value': 'RelHumSurf_QC', 'label': ''},
#    'RelHum_liquid': {'value': 'RelHum_liquid', 'label': ''},
#    'RelHum_liquid_QC': {'value': 'RelHum_liquid_QC', 'label': ''},
#    'RelHumSurf_liquid': {'value': 'RelHumSurf_liquid', 'label': ''},
#    'RelHumSurf_liquid_QC': {'value': 'RelHumSurf_liquid_QC', 'label': ''},
#    'GP_Tropopause': {'value': 'GP_Tropopause', 'label': ''},
#    'GP_Tropopause_QC': {'value': 'GP_Tropopause_QC', 'label': ''},
#    'GP_Height': {'value': 'GP_Height', 'label': ''},
#    'GP_Height_QC': {'value': 'GP_Height_QC', 'label': ''},
#    'GP_Surface': {'value': 'GP_Surface', 'label': ''},
#    'GP_Surface_QC': {'value': 'GP_Surface_QC', 'label': ''}},
#   'Cloud Formation Variables on 3 by 3 AIRS Fields of View': {'CldFrcTot': {'value': 'CldFrcTot',
#     'label': ''},
#    'CldFrcTot_QC': {'value': 'CldFrcTot_QC', 'label': ''},
#    'CldFrcStd': {'value': 'CldFrcStd', 'label': ''},
#    'CldFrcStd_QC': {'value': 'CldFrcStd_QC', 'label': ''},
#    'CldFrcStdErr': {'value': 'CldFrcStdErr', 'label': ''},
#    'PCldTop': {'value': 'PCldTop', 'label': ''},
#    'PCldTop_QC': {'value': 'PCldTop_QC', 'label': ''},
#    'PCldTopErr': {'value': 'PCldTopErr', 'label': ''},
#    'TCldTop': {'value': 'TCldTop', 'label': ''},
#    'TCldTop_QC': {'value': 'TCldTop_QC', 'label': ''},
#    'TCldTopErr': {'value': 'TCldTopErr', 'label': ''},
#    'nCld': {'value': 'nCld', 'label': ''}},
#   'Ozone Variables': {'totO3Std': {'value': 'totO3Std', 'label': ''},
#    'totO3Std_QC': {'value': 'totO3Std_QC', 'label': ''},
#    'totO3StdErr': {'value': 'totO3StdErr', 'label': ''},
#    'O3VMRStd': {'value': 'O3VMRStd', 'label': ''},
#    'O3VMRStd_QC': {'value': 'O3VMRStd_QC', 'label': ''},
#    'O3VMRStdErr': {'value': 'O3VMRStdErr', 'label': ''},
#    'O3VMRLevStd': {'value': 'O3VMRLevStd', 'label': ''},
#    'O3VMRLevStd_QC': {'value': 'O3VMRLevStd_QC', 'label': ''},
#    'O3VMRLevStdErr': {'value': 'O3VMRLevStdErr', 'label': ''},
#    'num_O3_Func': {'value': 'num_O3_Func', 'label': ''},
#    'O3_verticality': {'value': 'O3_verticality', 'label': ''},
#    'O3_dof': {'value': 'O3_dof', 'label': ''}},
#   'Carbon Monoxide Variables': {'COVMRLevStd': {'value': 'COVMRLevStd',
#     'label': ''},
#    'COVMRLevStd_QC': {'value': 'COVMRLevStd_QC', 'label': ''},
#    'COVMRLevStdErr': {'value': 'COVMRLevStdErr', 'label': ''},
#    'num_CO_Func': {'value': 'num_CO_Func', 'label': ''},
#    'CO_verticality': {'value': 'CO_verticality', 'label': ''},
#    'CO_dof': {'value': 'CO_dof', 'label': ''}},
#   'Methane Variables': {'CH4VMRLevStd': {'value': 'CH4VMRLevStd', 'label': ''},
#    'CH4VMRLevStd_QC': {'value': 'CH4VMRLevStd_QC', 'label': ''},
#    'CH4VMRLevStdErr': {'value': 'CH4VMRLevStdErr', 'label': ''},
#    'num_CH4_Func': {'value': 'num_CH4_Func', 'label': ''},
#    'CH4_verticality_10func': {'value': 'CH4_verticality_10func', 'label': ''},
#    'CH4_dof': {'value': 'CH4_dof', 'label': ''}},
#   'Outgoing Longwave Radiation Variables': {'olr': {'value': 'olr',
#     'label': ''},
#    'olr_QC': {'value': 'olr_QC', 'label': ''},
#    'olr3x3': {'value': 'olr3x3', 'label': ''},
#    'olr3x3_QC': {'value': 'olr3x3_QC', 'label': ''},
#    'olr_err': {'value': 'olr_err', 'label': ''},
#    'clrolr': {'value': 'clrolr', 'label': ''},
#    'clrolr_QC': {'value': 'clrolr_QC', 'label': ''},
#    'clrolr_err': {'value': 'clrolr_err', 'label': ''}},
#   'Geolocation QA Variables': {'ftptgeoqa': {'value': 'ftptgeoqa',
#     'label': ''},
#    'zengeoqa': {'value': 'zengeoqa', 'label': ''},
#    'demgeoqa': {'value': 'demgeoqa', 'label': ''}},
#   'Miscellaneous Variables': {'dust_flag': {'value': 'dust_flag', 'label': ''},
#    'all_spots_avg': {'value': 'all_spots_avg', 'label': ''},
#    'retrieval_type': {'value': 'retrieval_type', 'label': ''},
#    'SurfClass': {'value': 'SurfClass', 'label': ''}},
#   'Microwave Dependent Variables': {'TAirMWOnlyStd': {'value': 'TAirMWOnlyStd',
#     'label': ''},
#    'TAirMWOnlyStd_QC': {'value': 'TAirMWOnlyStd_QC', 'label': ''},
#    'MWSurfClass': {'value': 'MWSurfClass', 'label': ''},
#    'sfcTbMWStd': {'value': 'sfcTbMWStd', 'label': ''},
#    'sfcTbMWStd_QC': {'value': 'sfcTbMWStd_QC', 'label': ''},
#    'EmisMWStd': {'value': 'EmisMWStd', 'label': ''},
#    'EmisMWStd_QC': {'value': 'EmisMWStd_QC', 'label': ''},
#    'EmisMWStdErr': {'value': 'EmisMWStdErr', 'label': ''},
#    'totH2OMWOnlyStd': {'value': 'totH2OMWOnlyStd', 'label': ''},
#    'totH2OMWOnlyStd_QC': {'value': 'totH2OMWOnlyStd_QC', 'label': ''},
#    'GP_Height_MWOnly': {'value': 'GP_Height_MWOnly', 'label': ''},
#    'GP_Height_MWOnly_QC': {'value': 'GP_Height_MWOnly_QC', 'label': ''},
#    'MW_ret_used': {'value': 'MW_ret_used', 'label': ''},
#    'totCldH2OStd': {'value': 'totCldH2OStd', 'label': ''},
#    'totCldH2OStd_QC': {'value': 'totCldH2OStd_QC', 'label': ''},
#    'totCldH2OStdErr': {'value': 'totCldH2OStdErr', 'label': ''}}},
#  'AIRX2RET_006': {'Geolocation Fields': {'Latitude': {'value': 'Latitude',
#     'label': ''},
#    'Longitude': {'value': 'Longitude', 'label': ''},
#    'Time': {'value': 'Time', 'label': ''}},
#   'Attributes': {'processing_level': {'value': 'processing_level',
#     'label': ''},
#    'instrument': {'value': 'instrument', 'label': ''},
#    'DayNightFlag': {'value': 'DayNightFlag', 'label': ''},
#    'AutomaticQAFlag': {'value': 'AutomaticQAFlag', 'label': ''},
#    'NumTotalData': {'value': 'NumTotalData', 'label': ''},
#    'NumProcessData': {'value': 'NumProcessData', 'label': ''},
#    'NumSpecialData': {'value': 'NumSpecialData', 'label': ''},
#    'NumBadData': {'value': 'NumBadData', 'label': ''},
#    'NumMissingData': {'value': 'NumMissingData', 'label': ''},
#    'NumLandSurface': {'value': 'NumLandSurface', 'label': ''},
#    'NumOceanSurface': {'value': 'NumOceanSurface', 'label': ''},
#    'node_type': {'value': 'node_type', 'label': ''},
#    'start_year': {'value': 'start_year', 'label': ''},
#    'start_month': {'value': 'start_month', 'label': ''},
#    'start_day': {'value': 'start_day', 'label': ''},
#    'start_hour': {'value': 'start_hour', 'label': ''},
#    'start_minute': {'value': 'start_minute', 'label': ''},
#    'start_sec': {'value': 'start_sec', 'label': ''},
#    'start_orbit': {'value': 'start_orbit', 'label': ''},
#    'end_orbit': {'value': 'end_orbit', 'label': ''},
#    'orbit_path': {'value': 'orbit_path', 'label': ''},
#    'start_orbit_row': {'value': 'start_orbit_row', 'label': ''},
#    'end_orbit_row': {'value': 'end_orbit_row', 'label': ''},
#    'granule_number': {'value': 'granule_number', 'label': ''},
#    'num_scansets': {'value': 'num_scansets', 'label': ''},
#    'num_scanlines': {'value': 'num_scanlines', 'label': ''},
#    'start_Latitude': {'value': 'start_Latitude', 'label': ''},
#    'start_Longitude': {'value': 'start_Longitude', 'label': ''},
#    'start_Time': {'value': 'start_Time', 'label': ''},
#    'end_Latitude': {'value': 'end_Latitude', 'label': ''},
#    'end_Longitude': {'value': 'end_Longitude', 'label': ''},
#    'end_Time': {'value': 'end_Time', 'label': ''},
#    'eq_x_longitude': {'value': 'eq_x_longitude', 'label': ''},
#    'eq_x_tai': {'value': 'eq_x_tai', 'label': ''},
#    'LonGranuleCen': {'value': 'LonGranuleCen', 'label': ''},
#    'LatGranuleCen': {'value': 'LatGranuleCen', 'label': ''},
#    'LocTimeGranuleCen': {'value': 'LocTimeGranuleCen', 'label': ''},
#    'num_fpe': {'value': 'num_fpe', 'label': ''},
#    'orbitgeoqa': {'value': 'orbitgeoqa', 'label': ''},
#    'num_satgeoqa': {'value': 'num_satgeoqa', 'label': ''},
#    'num_glintgeoqa': {'value': 'num_glintgeoqa', 'label': ''},
#    'num_moongeoqa': {'value': 'num_moongeoqa', 'label': ''},
#    'num_ftptgeoqa': {'value': 'num_ftptgeoqa', 'label': ''},
#    'num_zengeoqa': {'value': 'num_zengeoqa', 'label': ''},
#    'num_demgeoqa': {'value': 'num_demgeoqa', 'label': ''},
#    'CO_first_guess': {'value': 'CO_first_guess', 'label': ''},
#    'CH4_first_guess': {'value': 'CH4_first_guess', 'label': ''},
#    'NumSO2FOVs': {'value': 'NumSO2FOVs', 'label': ''}},
#   'Ancillary Per-Granule Data Fields': {'pressStd': {'value': 'pressStd',
#     'label': ''},
#    'pressH2O': {'value': 'pressH2O', 'label': ''},
#    'MWHingeSurfFreqGHz': {'value': 'MWHingeSurfFreqGHz', 'label': ''}},
#   'Ancillary Along-Track Data Fields': {'satheight': {'value': 'satheight',
#     'label': ''},
#    'satroll': {'value': 'satroll', 'label': ''},
#    'satpitch': {'value': 'satpitch', 'label': ''},
#    'satyaw': {'value': 'satyaw', 'label': ''},
#    'glintlat': {'value': 'glintlat', 'label': ''},
#    'glintlon': {'value': 'glintlon', 'label': ''},
#    'nadirTAI': {'value': 'nadirTAI', 'label': ''},
#    'sat_lat': {'value': 'sat_lat', 'label': ''},
#    'sat_lon': {'value': 'sat_lon', 'label': ''},
#    'scan_node_type': {'value': 'scan_node_type', 'label': ''},
#    'satgeoqa': {'value': 'satgeoqa', 'label': ''},
#    'glintgeoqa': {'value': 'glintgeoqa', 'label': ''},
#    'moongeoqa': {'value': 'moongeoqa', 'label': ''}},
#   'Ancillary Full-Swath Geolocation Fields': {'satzen': {'value': 'satzen',
#     'label': ''},
#    'satazi': {'value': 'satazi', 'label': ''},
#    'solzen': {'value': 'solzen', 'label': ''},
#    'solazi': {'value': 'solazi', 'label': ''},
#    'sun_glint_distance': {'value': 'sun_glint_distance', 'label': ''}},
#   'Ancillary Full-Swath Surface Information from Geolocation': {'topog': {'value': 'topog',
#     'label': ''},
#    'topog_err': {'value': 'topog_err', 'label': ''},
#    'landFrac': {'value': 'landFrac', 'label': ''},
#    'landFrac_err': {'value': 'landFrac_err', 'label': ''},
#    'latAIRS': {'value': 'latAIRS', 'label': ''},
#    'lonAIRS': {'value': 'lonAIRS', 'label': ''},
#    'PSurfStd': {'value': 'PSurfStd', 'label': ''},
#    'PSurfStd_QC': {'value': 'PSurfStd_QC', 'label': ''},
#    'nSurfStd': {'value': 'nSurfStd', 'label': ''}},
#   'Quality Indicator Pressure Boundary Variables': {'PBest': {'value': 'PBest',
#     'label': ''},
#    'PGood': {'value': 'PGood', 'label': ''},
#    'nBestStd': {'value': 'nBestStd', 'label': ''},
#    'nGoodStd': {'value': 'nGoodStd', 'label': ''}},
#   'Surface Property Variables': {'TSurfStd': {'value': 'TSurfStd',
#     'label': ''},
#    'TSurfStd_QC': {'value': 'TSurfStd_QC', 'label': ''},
#    'TSurfStdErr': {'value': 'TSurfStdErr', 'label': ''},
#    'numHingeSurf': {'value': 'numHingeSurf', 'label': ''},
#    'freqEmis': {'value': 'freqEmis', 'label': ''},
#    'emisIRStd': {'value': 'emisIRStd', 'label': ''},
#    'emisIRStd_QC': {'value': 'emisIRStd_QC', 'label': ''},
#    'emisIRStdErr': {'value': 'emisIRStdErr', 'label': ''}},
#   'Air Temperature Variables': {'TAirStd': {'value': 'TAirStd', 'label': ''},
#    'TAirStd_QC': {'value': 'TAirStd_QC', 'label': ''},
#    'TAirStdErr': {'value': 'TAirStdErr', 'label': ''},
#    'TSurfAir': {'value': 'TSurfAir', 'label': ''},
#    'TSurfAir_QC': {'value': 'TSurfAir_QC', 'label': ''},
#    'TSurfAirErr': {'value': 'TSurfAirErr', 'label': ''},
#    'Temp_dof': {'value': 'Temp_dof', 'label': ''}},
#   'Water Vapor Saturation Variables Derived from Temperature': {'H2OMMRSat': {'value': 'H2OMMRSat',
#     'label': ''},
#    'H2OMMRSat_QC': {'value': 'H2OMMRSat_QC', 'label': ''},
#    'H2OMMRSatLevStd': {'value': 'H2OMMRSatLevStd', 'label': ''},
#    'H2OMMRSatLevStd_QC': {'value': 'H2OMMRSatLevStd_QC', 'label': ''},
#    'H2OMMRSatSurf': {'value': 'H2OMMRSatSurf', 'label': ''},
#    'H2OMMRSatSurf_QC': {'value': 'H2OMMRSatSurf_QC', 'label': ''},
#    'H2OMMRSat_liquid': {'value': 'H2OMMRSat_liquid', 'label': ''},
#    'H2OMMRSat_liquid_QC': {'value': 'H2OMMRSat_liquid_QC', 'label': ''},
#    'H2OMMRSatLevStd_liquid': {'value': 'H2OMMRSatLevStd_liquid', 'label': ''},
#    'H2OMMRSatLevStd_liquid_QC': {'value': 'H2OMMRSatLevStd_liquid_QC',
#     'label': ''},
#    'H2OMMRSatSurf_liquid': {'value': 'H2OMMRSatSurf_liquid', 'label': ''},
#    'H2OMMRSatSurf_liquid_QC': {'value': 'H2OMMRSatSurf_liquid_QC',
#     'label': ''}},
#   'Tropopause Variables Derived from Temperature': {'PTropopause': {'value': 'PTropopause',
#     'label': ''},
#    'PTropopause_QC': {'value': 'PTropopause_QC', 'label': ''},
#    'T_Tropopause': {'value': 'T_Tropopause', 'label': ''},
#    'T_Tropopause_QC': {'value': 'T_Tropopause_QC', 'label': ''}},
#   'Water Vapor Variables': {'totH2OStd': {'value': 'totH2OStd', 'label': ''},
#    'totH2OStd_QC': {'value': 'totH2OStd_QC', 'label': ''},
#    'totH2OStdErr': {'value': 'totH2OStdErr', 'label': ''},
#    'H2OMMRStd': {'value': 'H2OMMRStd', 'label': ''},
#    'H2OMMRStd_QC': {'value': 'H2OMMRStd_QC', 'label': ''},
#    'H2OMMRStdErr': {'value': 'H2OMMRStdErr', 'label': ''},
#    'H2OMMRLevStd': {'value': 'H2OMMRLevStd', 'label': ''},
#    'H2OMMRLevStd_QC': {'value': 'H2OMMRLevStd_QC', 'label': ''},
#    'H2OMMRLevStdErr': {'value': 'H2OMMRLevStdErr', 'label': ''},
#    'H2OMMRSurf': {'value': 'H2OMMRSurf', 'label': ''},
#    'H2OMMRSurf_QC': {'value': 'H2OMMRSurf_QC', 'label': ''},
#    'H2OMMRSurfErr': {'value': 'H2OMMRSurfErr', 'label': ''},
#    'num_H2O_Func': {'value': 'num_H2O_Func', 'label': ''},
#    'H2O_verticality': {'value': 'H2O_verticality', 'label': ''},
#    'H2O_dof': {'value': 'H2O_dof', 'label': ''}},
#   'Relative Humidity and Geopotential Height Variables from Temperature and Water Vapor': {'RelHum': {'value': 'RelHum',
#     'label': ''},
#    'RelHum_QC': {'value': 'RelHum_QC', 'label': ''},
#    'RelHumSurf': {'value': 'RelHumSurf', 'label': ''},
#    'RelHumSurf_QC': {'value': 'RelHumSurf_QC', 'label': ''},
#    'RelHum_liquid': {'value': 'RelHum_liquid', 'label': ''},
#    'RelHum_liquid_QC': {'value': 'RelHum_liquid_QC', 'label': ''},
#    'RelHumSurf_liquid': {'value': 'RelHumSurf_liquid', 'label': ''},
#    'RelHumSurf_liquid_QC': {'value': 'RelHumSurf_liquid_QC', 'label': ''},
#    'GP_Tropopause': {'value': 'GP_Tropopause', 'label': ''},
#    'GP_Tropopause_QC': {'value': 'GP_Tropopause_QC', 'label': ''},
#    'GP_Height': {'value': 'GP_Height', 'label': ''},
#    'GP_Height_QC': {'value': 'GP_Height_QC', 'label': ''},
#    'GP_Surface': {'value': 'GP_Surface', 'label': ''},
#    'GP_Surface_QC': {'value': 'GP_Surface_QC', 'label': ''}},
#   'Cloud Formation Variables on 3 by 3 AIRS Fields of View': {'CldFrcTot': {'value': 'CldFrcTot',
#     'label': ''},
#    'CldFrcTot_QC': {'value': 'CldFrcTot_QC', 'label': ''},
#    'CldFrcStd': {'value': 'CldFrcStd', 'label': ''},
#    'CldFrcStd_QC': {'value': 'CldFrcStd_QC', 'label': ''},
#    'CldFrcStdErr': {'value': 'CldFrcStdErr', 'label': ''},
#    'PCldTop': {'value': 'PCldTop', 'label': ''},
#    'PCldTop_QC': {'value': 'PCldTop_QC', 'label': ''},
#    'PCldTopErr': {'value': 'PCldTopErr', 'label': ''},
#    'TCldTop': {'value': 'TCldTop', 'label': ''},
#    'TCldTop_QC': {'value': 'TCldTop_QC', 'label': ''},
#    'TCldTopErr': {'value': 'TCldTopErr', 'label': ''},
#    'nCld': {'value': 'nCld', 'label': ''}},
#   'Ozone Variables': {'totO3Std': {'value': 'totO3Std', 'label': ''},
#    'totO3Std_QC': {'value': 'totO3Std_QC', 'label': ''},
#    'totO3StdErr': {'value': 'totO3StdErr', 'label': ''},
#    'O3VMRStd': {'value': 'O3VMRStd', 'label': ''},
#    'O3VMRStd_QC': {'value': 'O3VMRStd_QC', 'label': ''},
#    'O3VMRStdErr': {'value': 'O3VMRStdErr', 'label': ''},
#    'O3VMRLevStd': {'value': 'O3VMRLevStd', 'label': ''},
#    'O3VMRLevStd_QC': {'value': 'O3VMRLevStd_QC', 'label': ''},
#    'O3VMRLevStdErr': {'value': 'O3VMRLevStdErr', 'label': ''},
#    'num_O3_Func': {'value': 'num_O3_Func', 'label': ''},
#    'O3_verticality': {'value': 'O3_verticality', 'label': ''},
#    'O3_dof': {'value': 'O3_dof', 'label': ''}},
#   'Carbon Monoxide Variables': {'COVMRLevStd': {'value': 'COVMRLevStd',
#     'label': ''},
#    'COVMRLevStd_QC': {'value': 'COVMRLevStd_QC', 'label': ''},
#    'COVMRLevStdErr': {'value': 'COVMRLevStdErr', 'label': ''},
#    'num_CO_Func': {'value': 'num_CO_Func', 'label': ''},
#    'CO_verticality': {'value': 'CO_verticality', 'label': ''},
#    'CO_dof': {'value': 'CO_dof', 'label': ''}},
#   'Methane Variables': {'CH4VMRLevStd': {'value': 'CH4VMRLevStd', 'label': ''},
#    'CH4VMRLevStd_QC': {'value': 'CH4VMRLevStd_QC', 'label': ''},
#    'CH4VMRLevStdErr': {'value': 'CH4VMRLevStdErr', 'label': ''},
#    'num_CH4_Func': {'value': 'num_CH4_Func', 'label': ''},
#    'CH4_verticality_10func': {'value': 'CH4_verticality_10func', 'label': ''},
#    'CH4_dof': {'value': 'CH4_dof', 'label': ''}},
#   'Outgoing Longwave Radiation Variables': {'olr': {'value': 'olr',
#     'label': ''},
#    'olr_QC': {'value': 'olr_QC', 'label': ''},
#    'olr3x3': {'value': 'olr3x3', 'label': ''},
#    'olr3x3_QC': {'value': 'olr3x3_QC', 'label': ''},
#    'olr_err': {'value': 'olr_err', 'label': ''},
#    'clrolr': {'value': 'clrolr', 'label': ''},
#    'clrolr_QC': {'value': 'clrolr_QC', 'label': ''},
#    'clrolr_err': {'value': 'clrolr_err', 'label': ''}},
#   'Geolocation QA Variables': {'ftptgeoqa': {'value': 'ftptgeoqa',
#     'label': ''},
#    'zengeoqa': {'value': 'zengeoqa', 'label': ''},
#    'demgeoqa': {'value': 'demgeoqa', 'label': ''}},
#   'Miscellaneous Variables': {'dust_flag': {'value': 'dust_flag', 'label': ''},
#    'all_spots_avg': {'value': 'all_spots_avg', 'label': ''},
#    'retrieval_type': {'value': 'retrieval_type', 'label': ''},
#    'SurfClass': {'value': 'SurfClass', 'label': ''}},
#   'Microwave Dependent Variables': {'TAirMWOnlyStd': {'value': 'TAirMWOnlyStd',
#     'label': ''},
#    'TAirMWOnlyStd_QC': {'value': 'TAirMWOnlyStd_QC', 'label': ''},
#    'MWSurfClass': {'value': 'MWSurfClass', 'label': ''},
#    'sfcTbMWStd': {'value': 'sfcTbMWStd', 'label': ''},
#    'sfcTbMWStd_QC': {'value': 'sfcTbMWStd_QC', 'label': ''},
#    'EmisMWStd': {'value': 'EmisMWStd', 'label': ''},
#    'EmisMWStd_QC': {'value': 'EmisMWStd_QC', 'label': ''},
#    'EmisMWStdErr': {'value': 'EmisMWStdErr', 'label': ''},
#    'totH2OMWOnlyStd': {'value': 'totH2OMWOnlyStd', 'label': ''},
#    'totH2OMWOnlyStd_QC': {'value': 'totH2OMWOnlyStd_QC', 'label': ''},
#    'GP_Height_MWOnly': {'value': 'GP_Height_MWOnly', 'label': ''},
#    'GP_Height_MWOnly_QC': {'value': 'GP_Height_MWOnly_QC', 'label': ''},
#    'MW_ret_used': {'value': 'MW_ret_used', 'label': ''},
#    'totCldH2OStd': {'value': 'totCldH2OStd', 'label': ''},
#    'totCldH2OStd_QC': {'value': 'totCldH2OStd_QC', 'label': ''},
#    'totCldH2OStdErr': {'value': 'totCldH2OStdErr', 'label': ''}}},
#  'AIRH2SUP_006': {'Geolocation Fields': {'Latitude': {'value': 'Latitude',
#     'label': ''},
#    'Longitude': {'value': 'Longitude', 'label': ''},
# ...
#    'CC1_Noise_Amp': {'value': 'CC1_Noise_Amp', 'label': ''},
#    'Tsurf_4_CC1': {'value': 'Tsurf_4_CC1', 'label': ''},
#    'TotCld_4_CC1': {'value': 'TotCld_4_CC1', 'label': ''},
#    'CC1_RCode': {'value': 'CC1_RCode', 'label': ''},
#    'CC2_RCode': {'value': 'CC2_RCode', 'label': ''},
#    'Phys_RCode': {'value': 'Phys_RCode', 'label': ''},
#    'TotCld_below_500mb': {'value': 'TotCld_below_500mb', 'label': ''},
#    'Phys_resid_AMSUA': {'value': 'Phys_resid_AMSUA', 'label': ''},
#    'Phys_resid_IR_window_790': {'value': 'Phys_resid_IR_window_790',
#     'label': ''},
#    'Phys_resid_IR_window_844': {'value': 'Phys_resid_IR_window_844',
#     'label': ''},
#    'Phys_resid_IR_window_917': {'value': 'Phys_resid_IR_window_917',
#     'label': ''},
#    'Phys_resid_IR_window_1231': {'value': 'Phys_resid_IR_window_1231',
#     'label': ''},
#    'Phys_resid_IR_window_2513': {'value': 'Phys_resid_IR_window_2513',
#     'label': ''},
#    'Phys_resid_IR_window_2616': {'value': 'Phys_resid_IR_window_2616',
#     'label': ''},
#    'CBTmOBT1231': {'value': 'CBTmOBT1231', 'label': ''},
#    'CBTmOBT1231s': {'value': 'CBTmOBT1231s', 'label': ''},
#    'CC_noise_eff_amp_factor': {'value': 'CC_noise_eff_amp_factor',
#     'label': ''},
#    'CC1_noise_eff_amp_factor': {'value': 'CC1_noise_eff_amp_factor',
#     'label': ''},
#    'CC1_Resid': {'value': 'CC1_Resid', 'label': ''},
#    'CCfinal_Resid': {'value': 'CCfinal_Resid', 'label': ''},
#    'CCfinal_Noise_Amp': {'value': 'CCfinal_Noise_Amp', 'label': ''},
#    'Tdiff_IR_MW_ret': {'value': 'Tdiff_IR_MW_ret', 'label': ''},
#    'Tdiff_IR_4CC1': {'value': 'Tdiff_IR_4CC1', 'label': ''},
#    'TSurfdiff_IR_4CC1': {'value': 'TSurfdiff_IR_4CC1', 'label': ''},
#    'TSurfdiff_IR_4CC2': {'value': 'TSurfdiff_IR_4CC2', 'label': ''},
#    'AMSU_Chans_Resid': {'value': 'AMSU_Chans_Resid', 'label': ''},
#    'TotCld_4_CCfinal': {'value': 'TotCld_4_CCfinal', 'label': ''},
#    'Surf_Resid_Ratio': {'value': 'Surf_Resid_Ratio', 'label': ''},
#    'Temp_Resid_Ratio': {'value': 'Temp_Resid_Ratio', 'label': ''},
#    'Water_Resid_Ratio': {'value': 'Water_Resid_Ratio', 'label': ''},
#    'Cloud_Resid_Ratio3x3': {'value': 'Cloud_Resid_Ratio3x3', 'label': ''},
#    'Cloud_Resid_Ratio': {'value': 'Cloud_Resid_Ratio', 'label': ''},
#    'O3_Resid_Ratio': {'value': 'O3_Resid_Ratio', 'label': ''},
#    'CO_Resid_Ratio': {'value': 'CO_Resid_Ratio', 'label': ''},
#    'CH4_Resid_Ratio': {'value': 'CH4_Resid_Ratio', 'label': ''},
#    'MWCheck_Resid_Ratio': {'value': 'MWCheck_Resid_Ratio', 'label': ''},
#    'invalid': {'value': 'invalid', 'label': ''},
#    'MW_ret_used': {'value': 'MW_ret_used', 'label': ''},
#    'bad_clouds': {'value': 'bad_clouds', 'label': ''},
#    'Start_Clim': {'value': 'Start_Clim', 'label': ''},
#    'Startup': {'value': 'Startup', 'label': ''},
#    'cld_surf_fallback': {'value': 'cld_surf_fallback', 'label': ''},
#    'nchan_big_ang_adj': {'value': 'nchan_big_ang_adj', 'label': ''},
#    'bad_l1b': {'value': 'bad_l1b', 'label': ''},
#    'bad_l1b_amsu': {'value': 'bad_l1b_amsu', 'label': ''},
#    'bad_l1b_hsb': {'value': 'bad_l1b_hsb', 'label': ''},
#    'bad_l1b_airs': {'value': 'bad_l1b_airs', 'label': ''},
#    'bad_l1b_vis': {'value': 'bad_l1b_vis', 'label': ''},
#    'forecast': {'value': 'forecast', 'label': ''},
#    'no_psurf_guess': {'value': 'no_psurf_guess', 'label': ''},
#    'bad_temps': {'value': 'bad_temps', 'label': ''},
#    'bad_h2o': {'value': 'bad_h2o', 'label': ''},
#    'bad_o3': {'value': 'bad_o3', 'label': ''},
#    'bad_co': {'value': 'bad_co', 'label': ''},
#    'no_tuning': {'value': 'no_tuning', 'label': ''},
#    'no_ang_corr': {'value': 'no_ang_corr', 'label': ''},
#    'no_mw': {'value': 'no_mw', 'label': ''},
#    'no_initial': {'value': 'no_initial', 'label': ''},
#    'no_final': {'value': 'no_final', 'label': ''},
#    'mw_fpe': {'value': 'mw_fpe', 'label': ''},
#    'cloudy_reg_fpe': {'value': 'cloudy_reg_fpe', 'label': ''},
#    'initial_fpe': {'value': 'initial_fpe', 'label': ''},
#    'final_fpe': {'value': 'final_fpe', 'label': ''},
#    'MWPrecip': {'value': 'MWPrecip', 'label': ''},
#    'MWsurf_T0': {'value': 'MWsurf_T0', 'label': ''},
#    'MWsurf_Tinf': {'value': 'MWsurf_Tinf', 'label': ''},
#    'MWsecant_ratio': {'value': 'MWsecant_ratio', 'label': ''},
#    'MWseaice_conc': {'value': 'MWseaice_conc', 'label': ''},
#    'MWresidual_temp': {'value': 'MWresidual_temp', 'label': ''},
#    'MWresidual_mois': {'value': 'MWresidual_mois', 'label': ''},
#    'MWresidual_AMSUA': {'value': 'MWresidual_AMSUA', 'label': ''},
#    'MWresidual_HSB': {'value': 'MWresidual_HSB', 'label': ''},
#    'MWiter_temp': {'value': 'MWiter_temp', 'label': ''},
#    'MWiter_mois': {'value': 'MWiter_mois', 'label': ''},
#    'mw_ret_code': {'value': 'mw_ret_code', 'label': ''},
#    'sccnn_ret_code': {'value': 'sccnn_ret_code', 'label': ''},
#    'cloudy_reg_ret_code': {'value': 'cloudy_reg_ret_code', 'label': ''},
#    'Cloudy_Reg_FOV_chan': {'value': 'Cloudy_Reg_FOV_chan', 'label': ''},
#    'Cloudy_Reg_FOV': {'value': 'Cloudy_Reg_FOV', 'label': ''},
#    'Cloudy_Reg_FOV_BT': {'value': 'Cloudy_Reg_FOV_BT', 'label': ''},
#    'Cloudy_Reg_Score': {'value': 'Cloudy_Reg_Score', 'label': ''},
#    'cloud_ice': {'value': 'cloud_ice', 'label': ''},
#    'icc_too_cloudy': {'value': 'icc_too_cloudy', 'label': ''},
#    'icc_low_contrast': {'value': 'icc_low_contrast', 'label': ''},
#    'icc_bad_rad': {'value': 'icc_bad_rad', 'label': ''},
#    'icc_contrast': {'value': 'icc_contrast', 'label': ''},
#    'bad_1st': {'value': 'bad_1st', 'label': ''},
#    'bad_1st_surf': {'value': 'bad_1st_surf', 'label': ''},
#    'bad_1st_cc': {'value': 'bad_1st_cc', 'label': ''},
#    'bad_1st_regres': {'value': 'bad_1st_regres', 'label': ''},
#    'bad_1st_phys': {'value': 'bad_1st_phys', 'label': ''},
#    'fcc_too_cloudy': {'value': 'fcc_too_cloudy', 'label': ''},
#    'fcc_low_contrast': {'value': 'fcc_low_contrast', 'label': ''},
#    'fcc_bad_rad': {'value': 'fcc_bad_rad', 'label': ''},
#    'fcc_contrast1': {'value': 'fcc_contrast1', 'label': ''},
#    'fcc_contrast2': {'value': 'fcc_contrast2', 'label': ''},
#    'bad_final': {'value': 'bad_final', 'label': ''},
#    'bad_final_cc': {'value': 'bad_final_cc', 'label': ''},
#    'bad_final_ir': {'value': 'bad_final_ir', 'label': ''},
#    'bad_final_surf': {'value': 'bad_final_surf', 'label': ''},
#    'bad_final_temp': {'value': 'bad_final_temp', 'label': ''},
#    'bad_final_h2o': {'value': 'bad_final_h2o', 'label': ''},
#    'bad_final_o3': {'value': 'bad_final_o3', 'label': ''},
#    'bad_final_cloud': {'value': 'bad_final_cloud', 'label': ''},
#    'bad_cc_cld_ret': {'value': 'bad_cc_cld_ret', 'label': ''},
#    'MW_IR_ret_differ': {'value': 'MW_IR_ret_differ', 'label': ''},
#    'bad_MW_low_resid': {'value': 'bad_MW_low_resid', 'label': ''},
#    'MW_low_atm_resid': {'value': 'MW_low_atm_resid', 'label': ''},
#    'final_AMSU_ret': {'value': 'final_AMSU_ret', 'label': ''},
#    'final_HSB_ret': {'value': 'final_HSB_ret', 'label': ''},
#    'final_cloud_ret': {'value': 'final_cloud_ret', 'label': ''},
#    'final_cloud_spot_ret3x3': {'value': 'final_cloud_spot_ret3x3',
#     'label': ''},
#    'final_surf_ret': {'value': 'final_surf_ret', 'label': ''},
#    'final_temp_ret': {'value': 'final_temp_ret', 'label': ''},
#    'final_h2o_ret': {'value': 'final_h2o_ret', 'label': ''},
#    'final_o3_ret': {'value': 'final_o3_ret', 'label': ''},
#    'final_ch4_ret': {'value': 'final_ch4_ret', 'label': ''},
#    'final_co_ret': {'value': 'final_co_ret', 'label': ''},
#    'final_co2_ret': {'value': 'final_co2_ret', 'label': ''},
#    'bad_vis_rad': {'value': 'bad_vis_rad', 'label': ''},
#    'bad_vis_cal': {'value': 'bad_vis_cal', 'label': ''},
#    'bad_vis_det_temp': {'value': 'bad_vis_det_temp', 'label': ''},
#    'bad_scan_hd_temp': {'value': 'bad_scan_hd_temp', 'label': ''},
#    'Initial_CC_score': {'value': 'Initial_CC_score', 'label': ''},
#    'Initial_CC_subscores': {'value': 'Initial_CC_subscores', 'label': ''},
#    'sccnn_bt_corr': {'value': 'sccnn_bt_corr', 'label': ''},
#    'sccnn_bt_corr_freq': {'value': 'sccnn_bt_corr_freq', 'label': ''},
#    'relayer_num_nonpos_coef_h2o': {'value': 'relayer_num_nonpos_coef_h2o',
#     'label': ''},
#    'relayer_num_nonpos_coef_o3': {'value': 'relayer_num_nonpos_coef_o3',
#     'label': ''},
#    'relayer_num_nonpos_coef_co': {'value': 'relayer_num_nonpos_coef_co',
#     'label': ''},
#    'relayer_num_nonpos_coef_ch4': {'value': 'relayer_num_nonpos_coef_ch4',
#     'label': ''},
#    'relayer_num_knots': {'value': 'relayer_num_knots', 'label': ''},
#    'relayer_degree': {'value': 'relayer_degree', 'label': ''},
#    'relayer_runge_kutta_bits': {'value': 'relayer_runge_kutta_bits',
#     'label': ''},
#    'Num_Fill_Chan_Cloudy_Reg': {'value': 'Num_Fill_Chan_Cloudy_Reg',
#     'label': ''},
#    'Num_Fill_Chan_SCCNN': {'value': 'Num_Fill_Chan_SCCNN', 'label': ''},
#    'Num_Fill_Chan_Ang_Adj': {'value': 'Num_Fill_Chan_Ang_Adj', 'label': ''},
#    'Doppler_shift_ppm': {'value': 'Doppler_shift_ppm', 'label': ''},
#    'spectral_clear_indicator': {'value': 'spectral_clear_indicator',
#     'label': ''},
#    'num_clear_spectral_indicator': {'value': 'num_clear_spectral_indicator',
#     'label': ''}}},
#  'AIRH2CCF_7.0': {'channel ranges': {'0': {'value': [0, 130],
#     'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'},
#    '1': {'value': [130, 274],
#     'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'},
#    '2': {'value': [274, 441],
#     'label': 'channel range 275-441, frequency range 728.06/cm - 781.88/cm (long-wave surface)'},
#    '3': {'value': [441, 608],
#     'label': 'channel range 442-608, frequency range 789.26/cm - 852.43/cm (long-wave surface)'},
#    '4': {'value': [608, 769],
#     'label': 'channel range 609-769, frequency range 851.49/cm - 903.78/cm (long-wave surface)'},
#    '5': {'value': [769, 936],
#     'label': 'channel range 770-936, frequency range 911.24/cm - 974.29/cm (long-wave surface)'},
#    '6': {'value': [936, 1103],
#     'label': 'channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)'},
#    '7': {'value': [1103, 1262],
#     'label': 'channel range 1104-1262, frequency range 1056.10/cm - 1136.66/cm (long-wave surface, ozone)'},
#    '8': {'value': [1262, 1368],
#     'label': 'channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)'},
#    '9': {'value': [1368, 1462],
#     'label': 'channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)'},
#    '10': {'value': [1462, 1654],
#     'label': 'channel range 1463-1654, frequency range 1338.16/cm - 1443.07/cm (water vapor)'},
#    '11': {'value': [1654, 1760],
#     'label': 'channel range 1655-1760, frequency range 1460.27/cm - 1527.00/cm (water vapor)'},
#    '12': {'value': [1760, 1864],
#     'label': 'channel range 1761-1864, frequency range 1541.10/cm - 1613.86/cm (water vapor)'},
#    '13': {'value': [1864, 2014],
#     'label': 'channel range 1865-2014, frequency range 2181.50/cm - 2325.06/cm (shortwave temperature sounding, co)'},
#    '14': {'value': [2014, 2144],
#     'label': 'channel range 2015-2144, frequency range 2299.80/cm - 2422.85/cm (shortwave temperature sounding)'},
#    '15': {'value': [2144, 2260],
#     'label': 'channel range 2145-2260, frequency range 2446.20/cm - 2569.75/cm (shortwave surface)'},
#    '16': {'value': [2260, 2378],
#     'label': 'channel range 2261-2378, frequency range 2541.90/cm - 2665.24/cm (shortwave surface)'}}},
#  'AIRI2CCF_7.0': {'channel ranges': {'0': {'value': [0, 130],
#     'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'},
#    '1': {'value': [130, 274],
#     'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'},
#    '2': {'value': [274, 441],
#     'label': 'channel range 275-441, frequency range 728.06/cm - 781.88/cm (long-wave surface)'},
#    '3': {'value': [441, 608],
#     'label': 'channel range 442-608, frequency range 789.26/cm - 852.43/cm (long-wave surface)'},
#    '4': {'value': [608, 769],
#     'label': 'channel range 609-769, frequency range 851.49/cm - 903.78/cm (long-wave surface)'},
#    '5': {'value': [769, 936],
#     'label': 'channel range 770-936, frequency range 911.24/cm - 974.29/cm (long-wave surface)'},
#    '6': {'value': [936, 1103],
#     'label': 'channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)'},
#    '7': {'value': [1103, 1262],
#     'label': 'channel range 1104-1262, frequency range 1056.10/cm - 1136.66/cm (long-wave surface, ozone)'},
#    '8': {'value': [1262, 1368],
#     'label': 'channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)'},
#    '9': {'value': [1368, 1462],
#     'label': 'channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)'},
#    '10': {'value': [1462, 1654],
#     'label': 'channel range 1463-1654, frequency range 1338.16/cm - 1443.07/cm (water vapor)'},
#    '11': {'value': [1654, 1760],
#     'label': 'channel range 1655-1760, frequency range 1460.27/cm - 1527.00/cm (water vapor)'},
#    '12': {'value': [1760, 1864],
#     'label': 'channel range 1761-1864, frequency range 1541.10/cm - 1613.86/cm (water vapor)'},
#    '13': {'value': [1864, 2014],
#     'label': 'channel range 1865-2014, frequency range 2181.50/cm - 2325.06/cm (shortwave temperature sounding, co)'},
#    '14': {'value': [2014, 2144],
#     'label': 'channel range 2015-2144, frequency range 2299.80/cm - 2422.85/cm (shortwave temperature sounding)'},
#    '15': {'value': [2144, 2260],
#     'label': 'channel range 2145-2260, frequency range 2446.20/cm - 2569.75/cm (shortwave surface)'},
#    '16': {'value': [2260, 2378],
#     'label': 'channel range 2261-2378, frequency range 2541.90/cm - 2665.24/cm (shortwave surface)'}}},
#  'AIRS2CCF_7.0': {'channel ranges': {'0': {'value': [0, 130],
#     'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'},
#    '1': {'value': [130, 274],
#     'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'},
#    '2': {'value': [274, 441],
#     'label': 'channel range 275-441, frequency range 728.06/cm - 781.88/cm (long-wave surface)'},
#    '3': {'value': [441, 608],
#     'label': 'channel range 442-608, frequency range 789.26/cm - 852.43/cm (long-wave surface)'},
#    '4': {'value': [608, 769],
#     'label': 'channel range 609-769, frequency range 851.49/cm - 903.78/cm (long-wave surface)'},
#    '5': {'value': [769, 936],
#     'label': 'channel range 770-936, frequency range 911.24/cm - 974.29/cm (long-wave surface)'},
#    '6': {'value': [936, 1103],
#     'label': 'channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)'},
#    '7': {'value': [1103, 1262],
#     'label': 'channel range 1104-1262, frequency range 1056.10/cm - 1136.66/cm (long-wave surface, ozone)'},
#    '8': {'value': [1262, 1368],
#     'label': 'channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)'},
#    '9': {'value': [1368, 1462],
#     'label': 'channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)'},
#    '10': {'value': [1462, 1654],
#     'label': 'channel range 1463-1654, frequency range 1338.16/cm - 1443.07/cm (water vapor)'},
#    '11': {'value': [1654, 1760],
#     'label': 'channel range 1655-1760, frequency range 1460.27/cm - 1527.00/cm (water vapor)'},
#    '12': {'value': [1760, 1864],
#     'label': 'channel range 1761-1864, frequency range 1541.10/cm - 1613.86/cm (water vapor)'},
#    '13': {'value': [1864, 2014],
#     'label': 'channel range 1865-2014, frequency range 2181.50/cm - 2325.06/cm (shortwave temperature sounding, co)'},
#    '14': {'value': [2014, 2144],
#     'label': 'channel range 2015-2144, frequency range 2299.80/cm - 2422.85/cm (shortwave temperature sounding)'},
#    '15': {'value': [2144, 2260],
#     'label': 'channel range 2145-2260, frequency range 2446.20/cm - 2569.75/cm (shortwave surface)'},
#    '16': {'value': [2260, 2378],
#     'label': 'channel range 2261-2378, frequency range 2541.90/cm - 2665.24/cm (shortwave surface)'}}}}

# %% [markdown]
# ### 3. Define Helper Functions
#
# We use the OPeNDAP protocol to stream the data via `Xarray` and the `open_datatree` function. This is
# prefered over reading the AIRS granules directly as the HDF4-EOS2
# format is currently unable to be read via an `Xarray` compatible engine.

# %%
def parse_opendap(results):
    """Parse OPeNDAP URLs from earthaccess search results"""
    od_files = []
    for item in results:
        for urls in item['umm']['RelatedUrls']:
            if 'OPENDAP' in urls.get('Description', '').upper():
                url = urls['URL']
                url = url.replace("https", "dap4")
                od_files.append(url)
    print(f"Found {len(od_files)} OPeNDAP files")
    return od_files

def print_channel_ranges(ranges):
    for i, v in enumerate(ranges):
        print(f"Channel {i}")
        channel_i = ranges[str(i)]
        print(f"Range: {channel_i['value']}")
        print(f"Description: {channel_i['label']}")

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2: Channel Range Subsetting Examples
#
# Collections with channel ranges can be subset using index slicing on the
# channel dimension. All AIRS data which supports channel range subsetting have the same
# channels.
#
# The example below demonstrates channel range subsetting on the [AIRS2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_006/summary) collection, and can be adapted for the following collections, when a channel range has been identified:
# - [AIRIBRAD_005](https://disc.gsfc.nasa.gov/datasets/AIRIBRAD_005/summary?keywords=AIRIBRAD_005)
# - [AIRS2CCF_7.0](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_7.0/summary?keywords=AIRS2CCF_7.0)
# - [AIRH2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRH2CCF_006/summary?keywords=AIRH2CCF_006)

# %% [markdown]
# ---

# %% [markdown]
# ### Example 1. Subset [AIRS2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_006/summary)
#
# **Channel Ranges Available:** 17 ranges (0-16)
#
# #### Search for OPeNDAP URLs

# %%
# Search and retrieve data
results = earthaccess.search_data(
    short_name="AIRS2CCF",
    version='006',
    temporal=('2003-01-02', '2003-01-02'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 139 OPeNDAP files

# %% [markdown]
# #### Subset Water Vapor Channels (Channel Range 1263-1368, Frequency Range 1216.97/cm - 1272.59/cm)

# %%
# Open dataset
fp = od_files[0]
dt = xr.open_datatree(fp)

AIRS2CCF_006_channels = full_map["AIRS2CCF_006"]["channel ranges"]
channel_range_8 = AIRS2CCF_006_channels["8"]["value"]
dt_subset = dt.isel(Channel=slice(*channel_range_8))

print(f"Subset to: {AIRS2CCF_006_channels['8']['label']}")
print(dt_subset.dims)
# Out:
# Subset to: channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)
# Frozen(ChainMap({'GeoTrack': 45, 'GeoXTrack': 30, 'Channel': 106, 'AIRSTrack': 3, 'AIRSXTrack': 3, 'Module': 17}))

# %% [markdown]
# #### Subset with Multiple Channel Ranges
#
# We can also select multiple sequential channels via slicing.

# %%
ranges_to_combine = [
    AIRS2CCF_006_channels["8"]["value"],
    AIRS2CCF_006_channels["9"]["value"]
]

# Create combined slice (note: this assumes contiguous ranges)
combined_start = ranges_to_combine[0][0]
combined_end = ranges_to_combine[1][1]
dt_combined = dt.isel(Channel=slice(combined_start, combined_end))

print(f"Subset to: {AIRS2CCF_006_channels['8']['label']}")
print(dt_subset.dims)
# Out:
# Subset to: channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)
# Frozen(ChainMap({'GeoTrack': 45, 'GeoXTrack': 30, 'Channel': 106, 'AIRSTrack': 3, 'AIRSXTrack': 3, 'Module': 17}))

# %% [markdown]
# ---

# %% [markdown]
# ## Section 3: Variable Group Subsetting Examples
#
# Collections with variable groups allow subsetting by selecting specific
# variables from thematic groups.
#
# Available groups
#
# -  Geolocation Fields
# -  Attributes
# -  Ancillary Per-Granule Data Fields
# -  Ancillary Along-Track Data Fields
# -  Ancillary Full-Swath Geolocation Fields
# -  Ancillary Full-Swath Surface Information from Geolocation
# -  Quality Indicator Pressure Boundary Variables
# -  Surface Property Variables
# -  Air Temperature Variables
# -  Water Vapor Saturation Variables Derived from Temperature
# -  Tropopause Variables Derived from Temperature
# -  Water Vapor Variables
# -  Relative Humidity and Geopotential Height Variables from Temperature
#     and Water Vapor
# -  Cloud Formation Variables on 3 by 3 AIRS Fields of View
# -  Ozone Variables
# -  Carbon Monoxide Variables
# -  Methane Variables
# -  Outgoing Longwave Radiation Variables
# -  Geolocation QA Variables
# -  Miscellaneous Variables
# -  Microwave Dependent Variables
#
# The example below will use [AIRH2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_006/summary?keywords=AIRS2RET_006) and can be adapted to the following collections once a group from the mapping has been identified:
#
# - [AIRS2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_006/summary?keywords=AIRS2RET_006)
# - [AIRS2RET_7.0](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_7.0/summary?keywords=AIRS2RET_7.0)
# - [AIRX2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRX2RET_006/summary?keywords=AIRX2RET_006)
# - [AIRX2RET_7.0](https://disc.gsfc.nasa.gov/datasets/AIRX2RET_7.0/summary?keywords=AIRX2RET_7.0)
#
# ### Example 1: Subset [AIRH2RET_006](https://cmr.earthdata.nasa.gov/search/concepts/C1243477376-GES_DISC/9)
#
# #### Search for OPeNDAP URLs

# %%
results = earthaccess.search_data(
    short_name="AIRH2RET",
    version='006',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 9 OPeNDAP files

# %% [markdown]
# #### Open First File and Get Variable Group Configuration

# %%
# Open full datatree
AIRH2RET_006_fp = od_files[0]
AIRH2RET_006_dt = xr.open_datatree(AIRH2RET_006_fp)

# Get variable group configuration
AIRH2RET_006_map = full_map["AIRH2RET_006"]

# %% [markdown]
# #### Subset Relative Humidity Variables

# %%
rh_vars = list(AIRH2RET_006_map["Relative Humidity and Geopotential Height Variables from Temperature and Water Vapor"].keys())

# Navigate to the data group in the datatree
data_path = AIRH2RET_006_dt.L2_Standard_atmospheric_surface_product.Data_Fields

# Create subset - this subsets data variables but preserves coordinates
dt_rh_subset = data_path.copy()
dt_rh_subset.ds = data_path.ds[rh_vars]

print("Relative Humidity subset variables:")
print(list(dt_rh_subset.ds.data_vars))
# Out:
# Relative Humidity subset variables:
# ['RelHum', 'RelHum_QC', 'RelHumSurf', 'RelHumSurf_QC', 'RelHum_liquid', 'RelHum_liquid_QC', 'RelHumSurf_liquid', 'RelHumSurf_liquid_QC', 'GP_Tropopause', 'GP_Tropopause_QC', 'GP_Height', 'GP_Height_QC', 'GP_Surface', 'GP_Surface_QC']

# %% [markdown]
# #### Subset Methane Variables

# %%
cloud_vars = list(AIRH2RET_006_map["Methane Variables"].keys())
dt_cloud_subset = data_path.copy()
dt_cloud_subset.ds = data_path.ds[cloud_vars]
print("Relative Humidity subset variables:")
print(list(dt_rh_subset.ds.data_vars))
# Out:
# Relative Humidity subset variables:
# ['RelHum', 'RelHum_QC', 'RelHumSurf', 'RelHumSurf_QC', 'RelHum_liquid', 'RelHum_liquid_QC', 'RelHumSurf_liquid', 'RelHumSurf_liquid_QC', 'GP_Tropopause', 'GP_Tropopause_QC', 'GP_Height', 'GP_Height_QC', 'GP_Surface', 'GP_Surface_QC']

# %% [markdown]
# #### Subset Multiple Variable Groups

# %%
ozone_vars = list(AIRH2RET_006_map["Ozone Variables"].keys())
co_vars = list(AIRH2RET_006_map["Carbon Monoxide Variables"].keys())
combined_vars = ozone_vars + co_vars

dt_combined_subset = data_path.copy()
dt_combined_subset.ds = data_path.ds[combined_vars]

print(f"Combined subset has {len(dt_combined_subset.ds.data_vars)} variables")
# Out:
# Combined subset has 18 variables

# %% [markdown]
# ---

# %% [markdown]
# ## Section 4. Individual Channel Subsetting
#
# Collections with discrete channel definitions can be subset by selecting
# specific channels.
#
# ### Example 1. Subset [AIRABRAD_005](https://disc.gsfc.nasa.gov/datasets/AIRABRAD_005/summary?keywords=AIRABRAD_005)
#
# #### Search for OPeNDAP URLs

# %%
results = earthaccess.search_data(
    short_name="AIRABRAD",
    version='005',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 131 OPeNDAP files

# %% [markdown]
# #### Open First File

# %%
fp = od_files[0]
dt = xr.open_datatree(fp)

# %% [markdown]
# #### Subset to channel 5 (53.596 ± 0.115 GHz)

# %%
AIRABRAD_005_channels = full_map["AIRABRAD_005"]["channels"]

channel_5 = AIRABRAD_005_channels["5"]["value"]
dt_subset = dt.isel(Channel=channel_5 - 1)  # Convert to 0-based index

print(f"Selected: {AIRABRAD_005_channels['5']['label']}")
# Out:
# Selected: channel 5, frequency 53.596 ± 0.115 ghz

# %% [markdown]
# #### Subset to multiple specific channels

# %%
channels_to_select = [1, 5, 9]  # Select channels 1, 5, and 9
channel_indices = [AIRABRAD_005_channels[str(ch)]["value"] - 1 for ch in channels_to_select]
dt_multi_channel = dt.isel(Channel=channel_indices)

print(f"Selected {len(channels_to_select)} channels")
# Out:
# Selected 3 channels

# %% [markdown]
# ### Example 2. Subset [AIRVBRAD_005]()

# %%
# Search and retrieve data
results = earthaccess.search_data(
    short_name="AIRVBRAD",
    version='005',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 1 OPeNDAP files

# %%
# Open dataset
fp = od_files[0]
dt = xr.open_datatree(fp)

# %% [markdown]
# #### Subset to channel 2 (0.58-0.68 µm)

# %%
# Get channel configuration
AIRVBRAD_005_channels = full_map["AIRVBRAD_005"]["channels"]
channel_2 = AIRVBRAD_005_channels["2"]["value"]
dt_subset = dt.isel(Channel=channel_2 - 1)

print(f"Selected: {AIRVBRAD_005_channels['2']['label']}")
# Out:
# Selected: channel 2, wavelength 0.58-0.68 µm

# %% [markdown]
# #### Subset multiple channels

# %%
visible_channels = [1, 2]
channel_indices = [AIRVBRAD_005_channels[str(ch)]["value"] - 1 for ch in visible_channels]
dt_visible = dt.isel(Channel=channel_indices)
print(dt_visible)
# Out:
# <xarray.DataTree>
# Group: /
#     Dimensions:                             (GeoTrack: 135, GeoXTrack: 90,
#                                              Channel: 2, SubTrack: 9, SubXTrack: 8,
#                                              GeoLocationsPerSpot: 4)
#     Coordinates:
#         xtrack_err                          (Channel) float32 8B ...
#         Latitude                            (GeoTrack, GeoXTrack) float64 97kB ...
#         Longitude                           (GeoTrack, GeoXTrack) float64 97kB ...
#       * SubTrack                            (SubTrack) int32 36B 0 1 2 3 4 5 6 7 8
#       * SubXTrack                           (SubXTrack) int32 32B 0 1 2 3 4 5 6 7
#       * GeoLocationsPerSpot                 (GeoLocationsPerSpot) int32 16B 0 1 2 3
#     Dimensions without coordinates: GeoTrack, GeoXTrack, Channel
#     Data variables: (12/199)
#         radiances                           (GeoTrack, GeoXTrack, Channel, SubTrack, SubXTrack) float32 7MB ...
#         offset                              (GeoTrack, Channel, SubTrack) float32 10kB ...
#         offset_err                          (GeoTrack, Channel, SubTrack) float32 10kB ...
#         NeN                                 (GeoTrack, Channel, SubTrack) float32 10kB ...
#         PrelimCldQA                         (GeoTrack, GeoXTrack) int32 49kB ...
#         PrelimCldFracVis                    (GeoTrack, GeoXTrack) float32 49kB ...
#         ...                                  ...
#         state                               (GeoTrack, GeoXTrack) float64 97kB ...
#         track_err                           (Channel) float32 8B ...
#         OpMode                              (GeoTrack) uint16 270B ...
#         cornerlats                          (GeoTrack, GeoXTrack, GeoLocationsPerSpot, Channel) float32 389kB ...
#         cornerlons                          (GeoTrack, GeoXTrack, GeoLocationsPerSpot, Channel) float32 389kB ...
#         Time                                (GeoTrack, GeoXTrack) float64 97kB ...
