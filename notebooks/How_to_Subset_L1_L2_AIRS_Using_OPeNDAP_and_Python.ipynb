# %% [markdown]
# # How to Subset L1/L2 AIRS Data Using OPeNDAP and Python
#
# ### Authors: Owen Smith, Jennifer Adams, Chris Battisto
# ### Date Authored: 10-15-2025
#
# ### Timing
#
# Exercise: 5 minutes
#
# ### Overview
#
# The retired SUBSET_AIRS_L1L2 service provided dimension based channel
# subsetting, in addition to both individual variable subsetting and
# variable subsetting based on thematic groups.
#
# This notebook demonstrates subsetting operations for all AIRS
# collections using xarray and the curated subsetting groups from
# `ancillary/subset_airs.json`. The groups and variables provided via
# the json file provides 1:1 functionality with what the retired
# SUBSET_AIRS_L1L2 provided.
#
# All subsetting is performed via xarray. For more information on the xarray datatree structure please see [the xarray documentation on hierarchical data](https://docs.xarray.dev/en/latest/user-guide/hierarchical-data.html).
#
# ### Prerequisites
#
# This notebook was written using Python 3.10, and requires:
# - Valid [Earthdata Login credentials](https://urs.earthdata.nasa.gov), and the generation of [Earthdata Prerequisite Files](https://disc.gsfc.nasa.gov/information/howto?title=How%20to%20Generate%20Earthdata%20Prerequisite%20Files) including the <code>.netrc</code> and `.dodsrc` files.
# - [Xarray](https://docs.xarray.dev/en/stable/)
# - [earthaccess](https://earthaccess.readthedocs.io/en/latest/)
#
# #### Optional Anaconda Environment YAML:
#
# This notebook can be run using the ['nasa-gesdisc-opendap' YAML file](https://github.com/nasa/gesdisc-tutorials/tree/main/environments/nasa-gesdisc-opendap.yml) provided in the 'environments' subfolder.
#
# Please follow the instructions [here](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-from-an-environment-yml-file) to install and activate this environment.

# %% [markdown]
# ---

# %% [markdown]
# ## Section 1: Setup
#
# ### 1. Import Required Libraries

# %%
import xarray as xr
import earthaccess
import json
import urllib.request
import re

# Authenticate with earthaccess
auth = earthaccess.login()

# %% [markdown]
# ### 2. Load `subset_airs.json`
#
# The `subset_airs.json` file is stored in the `gesdisc-tutorials` repository, and is streamed to the `subset_airs` variable in the current notebook session.
#
# The file contains channel and frequency values, and their associated dimensional indices, to assist with creating our subsets.

# %%
url = 'https://raw.githubusercontent.com/nasa/gesdisc-tutorials/refs/heads/main/ancillary/subset_airs.json'
with urllib.request.urlopen(url) as response:
    subset_airs_map = json.load(response)

print(subset_airs_map)
# Out:
# {'AIRABRAD_005': {'channels': {'1': {'value': 1, 'label': 'channel 1, frequency 23.800 ghz'}, '2': {'value': 2, 'label': 'channel 2, frequency 31.400 ghz'}, '3': {'value': 3, 'label': 'channel 3, frequency 50.300 ghz'}, '4': {'value': 4, 'label': 'channel 4, frequency 52.800 ghz'}, '5': {'value': 5, 'label': 'channel 5, frequency 53.596 ± 0.115 ghz'}, '6': {'value': 6, 'label': 'channel 6, frequency 54.400 ghz'}, '7': {'value': 7, 'label': 'channel 7, frequency 54.940 ghz'}, '8': {'value': 8, 'label': 'channel 8, frequency 55.500 ghz'}, '9': {'value': 9, 'label': 'channel 9, frequency 57.290344 ghz'}, '10': {'value': 10, 'label': 'channel 10, frequency 57.290344 ± 0.217 ghz'}, '11': {'value': 11, 'label': 'channel 11, frequency 57.290344 ± 0.3224 ± 0.048 ghz'}, '12': {'value': 12, 'label': 'channel 12, frequency 57.290344 ± 0.3224 ± 0.022 ghz'}, '13': {'value': 13, 'label': 'channel 13, frequency 57.290344 ± 0.3224 ± 0.010 ghz'}, '14': {'value': 14, 'label': 'channel 14, frequency 57.290344 ± 0.3224 ± 0.0045 ghz'}, '15': {'value': 15, 'label': 'channel 15, frequency 89.000 ghz'}}}, 'AIRHBRAD_005': {'channels': {'2': {'value': 2, 'label': 'channel 2, frequency 150.0 ghz'}, '3': {'value': 3, 'label': 'channel 3, frequency 183.31 ± 1.0 ghz'}, '4': {'value': 4, 'label': 'channel 4, frequency 183.31 ± 3.0 ghz'}, '5': {'value': 5, 'label': 'channel 5, frequency 183.31 ± 7.0 ghz'}}}, 'AIRVBRAD_005': {'channels': {'1': {'value': 1, 'label': 'channel 1, wavelength 0.40-0.44 µm'}, '2': {'value': 2, 'label': 'channel 2, wavelength 0.58-0.68 µm'}, '3': {'value': 3, 'label': 'channel 3, wavelength 0.71-0.92 µm'}, '4': {'value': 4, 'label': 'channel 4, wavelength 0.49-0.94 µm'}}}, 'AIRXBCAL_005': {'Variables': {'amsu_bt': {'value': 'amsu_bt', 'label': ''}, 'amsu_landFrac': {'value': 'amsu_landFrac', 'label': ''}, 'amsu_topog': {'value': 'amsu_topog', 'label': ''}, 'avnsst': {'value': 'avnsst', 'label': ''}, 'bt1231': {'value': 'bt1231', 'label': ''}, 'BT_diff_SO2': {'value': 'BT_diff_SO2', 'label': ''}, 'cx1231': {'value': 'cx1231', 'label': ''}, 'cx2395': {'value': 'cx2395', 'label': ''}, 'cx2616': {'value': 'cx2616', 'label': ''}, 'cxlpn': {'value': 'cxlpn', 'label': ''}, 'cxq2': {'value': 'cxq2', 'label': ''}, 'dust_flag': {'value': 'dust_flag', 'label': ''}, 'footprint': {'value': 'footprint', 'label': ''}, 'granule_number': {'value': 'granule_number', 'label': ''}, 'LandFrac': {'value': 'LandFrac', 'label': ''}, 'lp2395clim': {'value': 'lp2395clim', 'label': ''}, 'nominal_freq': {'value': 'nominal_freq', 'label': ''}, 'radiances': {'value': 'radiances', 'label': 'radiances (will automatically be included if any channel ranges are selected)'}, 'reason': {'value': 'reason', 'label': ''}, 'satheight': {'value': 'satheight', 'label': ''}, 'satzen': {'value': 'satzen', 'label': ''}, 'scan': {'value': 'scan', 'label': ''}, 'scan_node_type': {'value': 'scan_node_type', 'label': ''}, 'site': {'value': 'site', 'label': ''}, 'solzen': {'value': 'solzen', 'label': ''}, 'sst1231r5': {'value': 'sst1231r5', 'label': ''}, 'sun_glint_distance': {'value': 'sun_glint_distance', 'label': ''}, 'topog': {'value': 'topog', 'label': ''}, 'VisMean': {'value': 'VisMean', 'label': ''}, 'VisStdDev': {'value': 'VisStdDev', 'label': ''}}, 'Reason Codes (optional; multiple selections may result in an empty subset)': {'ReasonCode 1': {'value': 'ReasonCode 1', 'label': 'reason code 1: clear'}, 'ReasonCode 2': {'value': 'ReasonCode 2', 'label': 'reason code 2: special calibration site'}, 'ReasonCode 4': {'value': 'ReasonCode 4', 'label': 'reason code 4: high clouds'}, 'ReasonCode 8': {'value': 'ReasonCode 8', 'label': 'reason code 8: random sample'}}, 'Channel Ranges for radiances': {'0': {'value': [0, 130], 'label': 'channel range 1-130, frequency range 649.61/cm - 681.99/cm (long-wave temperature sounding)'}, '1': {'value': [130, 274], 'label': 'channel range 131-274, frequency range 687.60/cm - 728.44/cm (long-wave temperature sounding)'}, '2': {'value': [274, 441] ...

# %% [markdown]
# ### 3. Define Helper Functions
#
# We use the OPeNDAP protocol to stream the data via `Xarray` and the `open_datatree` function. This is
# prefered over reading the AIRS granules directly as the HDF4-EOS2
# format is currently unable to be read via an `Xarray` compatible engine.

# %%
def parse_opendap(results):
    """Parse OPeNDAP URLs from earthaccess search results"""
    od_files = []
    for item in results:
        for urls in item['umm']['RelatedUrls']:
            if 'OPENDAP' in urls.get('Description', '').upper():
                url = urls['URL']
                url = url.replace("https", "dap4")
                od_files.append(url)
    print(f"Found {len(od_files)} OPeNDAP files")
    return od_files

def print_channel_ranges(ranges):
    for i, v in enumerate(ranges):
        print(f"Channel {i}")
        channel_i = ranges[str(i)]
        print(f"Range: {channel_i['value']}")
        print(f"Description: {channel_i['label']}")


def get_dim_name(dt: xr.DataTree, base_name: str) -> str:
    """
    Find the full dimension name from a root datatree that starts with a given base name.
    
    Raises ValueError if no match or multiple matches are found.
    """

    # python caches compiled regexes, so it is safe to keep this within the func
    dim_name_pattern = re.compile(rf"^{re.escape(base_name)}(_\w+)?$")
    matches = [dim for dim in dt.dims if dim_name_pattern.match(dim)]
    
    if len(matches) == 1:
        return matches[0]
    elif len(matches) == 0:
        raise ValueError(
            f"No dimension found starting with '{base_name}'. "
            f"Available dimensions: {list(dt.dims)}"
        )
    else:
        raise ValueError(
            f"Multiple dimensions found starting with '{base_name}': {matches}. "
            f"Please use a more specific base name."
        )

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2: Channel Range Subsetting Examples
#
# Collections with channel ranges can be subset using index slicing on the
# channel dimension. All AIRS data which supports channel range subsetting have the same
# channels.
#
# The example below demonstrates channel range subsetting on the [AIRS2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_006/summary) collection, and can be adapted for the following collections, when a channel range has been identified:
# - [AIRIBRAD_005](https://disc.gsfc.nasa.gov/datasets/AIRIBRAD_005/summary?keywords=AIRIBRAD_005)
# - [AIRS2CCF_7.0](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_7.0/summary?keywords=AIRS2CCF_7.0)
# - [AIRH2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRH2CCF_006/summary?keywords=AIRH2CCF_006)

# %% [markdown]
# ---

# %% [markdown]
# ### Example 1. Subset [AIRS2CCF_006](https://disc.gsfc.nasa.gov/datasets/AIRS2CCF_006/summary)
#
# **Channel Ranges Available:** 17 ranges (0-16)
#
# #### Search for OPeNDAP URLs

# %%
# Search and retrieve data
results = earthaccess.search_data(
    short_name="AIRS2CCF",
    version='006',
    temporal=('2003-01-02', '2003-01-02'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 139 OPeNDAP files

# %% [markdown]
# #### Subset Water Vapor Channels (Channel Range 1263-1368, Frequency Range 1216.97/cm - 1272.59/cm)

# %%
# Open dataset
fp = od_files[0]
dt = xr.open_datatree(fp)

AIRS2CCF_006_channels = subset_airs_map["AIRS2CCF_006"]["channel ranges"]
channel_range_8 = AIRS2CCF_006_channels["8"]["value"]

# The channel dimension gets renamed in OPeNDAP, so for most collections we can 
# use the `get_dim_name` to derive the channel name. Otherwise if you know the 
# dimension name, you can just use that instead, 
channel_dim = get_dim_name(dt, "Channel")

# The following is functionally the same
# indexer = {"Channel_L2_Standard_cloud_cleared_radiance_product": slice(*channel_range_8)}
indexer = {channel_dim: slice(*channel_range_8)}

dt_subset = dt.isel(indexer)

print(f"Subset to: {AIRS2CCF_006_channels['8']['label']}")
print(dt_subset.dims)
# Out:
# checksumhack=0
# Subset to: channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)
# Frozen(ChainMap({'GeoTrack_L2_Standard_cloud_cleared_radiance_product': 45, 'GeoXTrack_L2_Standard_cloud_cleared_radiance_product': 30, 'Channel_L2_Standard_cloud_cleared_radiance_product': 106, 'AIRSTrack_L2_Standard_cloud_cleared_radiance_product': 3, 'AIRSXTrack_L2_Standard_cloud_cleared_radiance_product': 3}))

# %% [markdown]
# #### Subset with Multiple Channel Ranges
#
# We can also select multiple sequential channels via slicing.

# %%
ranges_to_combine = [
    AIRS2CCF_006_channels["8"]["value"],
    AIRS2CCF_006_channels["9"]["value"]
]

# Create combined slice (note: this assumes contiguous ranges)
combined_start = ranges_to_combine[0][0]
combined_end = ranges_to_combine[1][1]

channel_dim = get_dim_name(dt, "Channel")
indexer = {
    channel_dim: slice(combined_start, combined_end),
    }

dt_combined = dt.isel(indexer)

print(f"Subset to: \n{AIRS2CCF_006_channels['8']['label']} \n{AIRS2CCF_006_channels['9']['label']}")
print(dt_combined.dims)
# Out:
# Subset to:
# channel range 1263-1368, frequency range 1216.97/cm - 1272.59/cm (water vapor)
# channel range 1369-1462, frequency range 1284.35/cm - 1338.86/cm (water vapor, methane)
# Frozen(ChainMap({'GeoTrack_L2_Standard_cloud_cleared_radiance_product': 45, 'GeoXTrack_L2_Standard_cloud_cleared_radiance_product': 30, 'Channel_L2_Standard_cloud_cleared_radiance_product': 200, 'AIRSTrack_L2_Standard_cloud_cleared_radiance_product': 3, 'AIRSXTrack_L2_Standard_cloud_cleared_radiance_product': 3}))

# %% [markdown]
# ---

# %% [markdown]
# ## Section 3: Variable Group Subsetting Examples
#
# Collections with variable groups allow subsetting by selecting specific
# variables from thematic groups.
#
# Available groups
#
# -  Geolocation Fields
# -  Attributes
# -  Ancillary Per-Granule Data Fields
# -  Ancillary Along-Track Data Fields
# -  Ancillary Full-Swath Geolocation Fields
# -  Ancillary Full-Swath Surface Information from Geolocation
# -  Quality Indicator Pressure Boundary Variables
# -  Surface Property Variables
# -  Air Temperature Variables
# -  Water Vapor Saturation Variables Derived from Temperature
# -  Tropopause Variables Derived from Temperature
# -  Water Vapor Variables
# -  Relative Humidity and Geopotential Height Variables from Temperature
#     and Water Vapor
# -  Cloud Formation Variables on 3 by 3 AIRS Fields of View
# -  Ozone Variables
# -  Carbon Monoxide Variables
# -  Methane Variables
# -  Outgoing Longwave Radiation Variables
# -  Geolocation QA Variables
# -  Miscellaneous Variables
# -  Microwave Dependent Variables
#
# The example below will use [AIRH2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_006/summary?keywords=AIRS2RET_006) and can be adapted to the following collections once a group from the mapping has been identified:
#
# - [AIRS2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_006/summary?keywords=AIRS2RET_006)
# - [AIRS2RET_7.0](https://disc.gsfc.nasa.gov/datasets/AIRS2RET_7.0/summary?keywords=AIRS2RET_7.0)
# - [AIRX2RET_006](https://disc.gsfc.nasa.gov/datasets/AIRX2RET_006/summary?keywords=AIRX2RET_006)
# - [AIRX2RET_7.0](https://disc.gsfc.nasa.gov/datasets/AIRX2RET_7.0/summary?keywords=AIRX2RET_7.0)
#
# ### Example 1: Subset [AIRH2RET_006](https://cmr.earthdata.nasa.gov/search/concepts/C1243477376-GES_DISC/9)
#
# #### Search for OPeNDAP URLs

# %%
results = earthaccess.search_data(
    short_name="AIRH2RET",
    version='006',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 9 OPeNDAP files

# %% [markdown]
# #### Open First File and Get Variable Group Configuration

# %%
# Open full datatree
AIRH2RET_006_fp = od_files[0]
AIRH2RET_006_dt = xr.open_datatree(AIRH2RET_006_fp)

# Get variable group configuration
AIRH2RET_006_map = subset_airs_map["AIRH2RET_006"]
# Out:
# checksumhack=0

# %% [markdown]
# #### Subset Relative Humidity Variables

# %%
rh_vars = list(AIRH2RET_006_map["Relative Humidity and Geopotential Height Variables from Temperature and Water Vapor"].keys())

# Navigate to the data group in the datatree
data_path = AIRH2RET_006_dt.L2_Standard_atmospheric_surface_product.Data_Fields

# Create subset, this subsets data variables but preserves coordinates
dt_rh_subset = data_path.copy()
dt_rh_subset.ds = data_path.ds[rh_vars]

print("Relative Humidity subset variables:")
print(list(dt_rh_subset.ds.data_vars))
# Out:
# Relative Humidity subset variables:
# ['RelHum', 'RelHum_QC', 'RelHumSurf', 'RelHumSurf_QC', 'RelHum_liquid', 'RelHum_liquid_QC', 'RelHumSurf_liquid', 'RelHumSurf_liquid_QC', 'GP_Tropopause', 'GP_Tropopause_QC', 'GP_Height', 'GP_Height_QC', 'GP_Surface', 'GP_Surface_QC']

# %% [markdown]
# #### Subset Methane Variables

# %%
cloud_vars = list(AIRH2RET_006_map["Methane Variables"].keys())
dt_cloud_subset = data_path.copy()
dt_cloud_subset.ds = data_path.ds[cloud_vars]
print("Relative Humidity subset variables:")
print(list(dt_rh_subset.ds.data_vars))
# Out:
# Relative Humidity subset variables:
# ['RelHum', 'RelHum_QC', 'RelHumSurf', 'RelHumSurf_QC', 'RelHum_liquid', 'RelHum_liquid_QC', 'RelHumSurf_liquid', 'RelHumSurf_liquid_QC', 'GP_Tropopause', 'GP_Tropopause_QC', 'GP_Height', 'GP_Height_QC', 'GP_Surface', 'GP_Surface_QC']

# %% [markdown]
# #### Subset Multiple Variable Groups

# %%
ozone_vars = list(AIRH2RET_006_map["Ozone Variables"].keys())
co_vars = list(AIRH2RET_006_map["Carbon Monoxide Variables"].keys())
combined_vars = ozone_vars + co_vars

dt_combined_subset = data_path.copy()
dt_combined_subset.ds = data_path.ds[combined_vars]

print(f"Combined subset has {len(dt_combined_subset.ds.data_vars)} variables")
# Out:
# Combined subset has 18 variables

# %% [markdown]
# ---

# %% [markdown]
# ## Section 4. Individual Channel Subsetting
#
# Collections with discrete channel definitions can be subset by selecting
# specific channels.
#
# ### Example 1. Subset [AIRABRAD_005](https://disc.gsfc.nasa.gov/datasets/AIRABRAD_005/summary?keywords=AIRABRAD_005)
#
# #### Search for OPeNDAP URLs

# %%
results = earthaccess.search_data(
    short_name="AIRABRAD",
    version='005',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 131 OPeNDAP files

# %% [markdown]
# #### Open First File

# %%
fp = od_files[0]
dt = xr.open_datatree(fp)

# %% [markdown]
# #### Subset to channel 5 (53.596 ± 0.115 GHz)

# %%
AIRABRAD_005_channels = subset_airs_map["AIRABRAD_005"]["channels"]

channel_5 = AIRABRAD_005_channels["5"]["value"]
indexer = {"Channel_L1B_AMSU": channel_5 - 1}

dt_subset = dt.isel(indexer)  # Convert to 0-based index

print(f"Selected: {AIRABRAD_005_channels['5']['label']}")
# Out:
# Selected: channel 5, frequency 53.596 ± 0.115 ghz

# %% [markdown]
# #### Subset to multiple specific channels

# %%
channels_to_select = [1, 5, 9]  # Select channels 1, 5, and 9
channel_indices = [AIRABRAD_005_channels[str(ch)]["value"] - 1 for ch in channels_to_select]

indexer = {"Channel_L1B_AMSU": channel_indices}
dt_multi_channel = dt.isel(indexer)

print(f"Selected {len(channels_to_select)} channels")
# Out:
# Selected 3 channels

# %% [markdown]
# ### Example 2. Subset [AIRVBRAD_005]()

# %%
# Search and retrieve data
results = earthaccess.search_data(
    short_name="AIRVBRAD",
    version='005',
    temporal=('2002-08-30', '2002-08-30'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 1 OPeNDAP files

# %%
# Open dataset
fp = od_files[0]
dt = xr.open_datatree(fp)

# %% [markdown]
# #### Subset to channel 2 (0.58-0.68 µm)

# %%
# Get channel configuration
AIRVBRAD_005_channels = subset_airs_map["AIRVBRAD_005"]["channels"]
channel_2 = AIRVBRAD_005_channels["2"]["value"]

indexer = {"Channel_L1B_VIS_Science": channel_2 - 1}

dt_subset = dt.isel(indexer)


print(f"Selected: {AIRVBRAD_005_channels['2']['label']}")
# Out:
# Selected: channel 2, wavelength 0.58-0.68 µm

# %% [markdown]
# #### Subset multiple channels

# %%
visible_channels = [1, 2]
channel_indices = [AIRVBRAD_005_channels[str(ch)]["value"] - 1 for ch in visible_channels]

indexer = {"Channel_L1B_VIS_Science": channel_indices}

dt_visible = dt.isel(indexer)
print(dt_visible)
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       HDFEOSVersion:     HDFEOS_V2.12
# │       StructMetadata_0:  GROUP=SwathStructure\n\tGROUP=SWATH_1\n\t\tSwathName=&...
# │       coremetadata:      \nGROUP                  = INVENTORYMETADATA\n  GROUPT...
# └── Group: /L1B_VIS_Science
#     ├── Group: /L1B_VIS_Science/Geolocation_Fields
#     │       Dimensions:    (GeoTrack_L1B_VIS_Science: 135, GeoXTrack_L1B_VIS_Science: 90)
#     │       Dimensions without coordinates: GeoTrack_L1B_VIS_Science,
#     │                                       GeoXTrack_L1B_VIS_Science
#     │       Data variables:
#     │           Latitude   (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) float64 97kB ...
#     │           Longitude  (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) float64 97kB ...
#     │           Time       (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) float64 97kB ...
#     ├── Group: /L1B_VIS_Science/Data_Fields
#     │       Dimensions:                             (GeoTrack_L1B_VIS_Science: 135,
#     │                                                GeoXTrack_L1B_VIS_Science: 90,
#     │                                                Channel_L1B_VIS_Science: 2,
#     │                                                SubTrack_L1B_VIS_Science: 9,
#     │                                                SubXTrack_L1B_VIS_Science: 8,
#     │                                                _Anonymous135: 135, _Anonymous4: 4,
#     │                                                GeoLocationsPerSpot_L1B_VIS_Science: 4)
#     │       Dimensions without coordinates: GeoTrack_L1B_VIS_Science,
#     │                                       GeoXTrack_L1B_VIS_Science,
#     │                                       Channel_L1B_VIS_Science,
#     │                                       SubTrack_L1B_VIS_Science,
#     │                                       SubXTrack_L1B_VIS_Science, _Anonymous135,
#     │                                       _Anonymous4, GeoLocationsPerSpot_L1B_VIS_Science
#     │       Data variables: (12/199)
#     │           radiances                           (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science, Channel_L1B_VIS_Science, SubTrack_L1B_VIS_Science, SubXTrack_L1B_VIS_Science) float32 7MB ...
#     │           offset                              (GeoTrack_L1B_VIS_Science, Channel_L1B_VIS_Science, SubTrack_L1B_VIS_Science) float32 10kB ...
#     │           offset_err                          (GeoTrack_L1B_VIS_Science, Channel_L1B_VIS_Science, SubTrack_L1B_VIS_Science) float32 10kB ...
#     │           NeN                                 (GeoTrack_L1B_VIS_Science, Channel_L1B_VIS_Science, SubTrack_L1B_VIS_Science) float32 10kB ...
#     │           PrelimCldQA                         (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) int8 12kB ...
#     │           PrelimCldFracVis                    (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) float32 49kB ...
#     │           ...                                  ...
#     │           state                               (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science) float64 97kB ...
#     │           xtrack_err                          (_Anonymous4) float32 16B ...
#     │           track_err                           (_Anonymous4) float32 16B ...
#     │           OpMode                              (_Anonymous135) uint16 270B ...
#     │           cornerlats                          (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science, GeoLocationsPerSpot_L1B_VIS_Science, Channel_L1B_VIS_Science) float32 389kB ...
#     │           cornerlons                          (GeoTrack_L1B_VIS_Science, GeoXTrack_L1B_VIS_Science, GeoLocationsPerSpot_L1B_VIS_Science, Channel_L1B_VIS_Science) float32 389kB ...
#     └── Group: /L1B_VIS_Science/Swath_Attributes
#             Attributes: (12/87)
#                 SWATH_TITLE__:                       L1B_VIS_Science
#                 VISDarkAMSUFOVCount:                 0
#                 VISBrightAMSUFOVCount:               39
#                 processing_level:                    level1B
#                 instrument:                          VIS
#                 DayNightFlag:                        Day
#                 ...                                  ...
#                 align_2_3_nadir:                     0.05699999
#                 align_2_4_nadir:                     0.12399997
#                 align_1_2_maxang:                    0.07000001
#                 align_2_3_maxang:                    0.104999974
#                 align_2_4_maxang:                    0.22700003
#                 align_vis_airs:                      2.2999997

# %% [markdown]
# ---
#
# ## Section 5: Multi Swath Subsets

# %% [markdown]
# #### Example 1: AIRXBCAL_005
#
# The AIRXBCAL_005 collection has two swath groups,`L1B_AIRS_Cal_Subset` and `L1B_AIRS_Cal_Subset_Gran_Stats`, each with their own relevant dimensions.
#
# The following will show how to use the dimension names for each swatch group to perform a multi swath subset.

# %%
# Search and retrieve data
results = earthaccess.search_data(
    short_name="AIRXBCAL",
    version='005',
    temporal=('2002-05-30', '2002-08-31'),
    bounding_box=(-180, 0, 180, 90)
)
od_files = parse_opendap(results)
# Out:
# Found 1 OPeNDAP files

# %%
# Open dataset
fp = od_files[0]
dt = xr.open_datatree(fp)

# %%
# Get channel configuration
AIRXBCAL_005_channels = subset_airs_map["AIRXBCAL_005"]["Channel Ranges for radiances"]
channel_6 = AIRXBCAL_005_channels["6"]["value"]

indexer = {
    "IR_Channel_L1B_AIRS_Cal_Subset": slice(*channel_6),
    "IR_Channels_L1B_AIRS_Cal_Subset_Gran_Stats": slice(*channel_6),
}

dt_subset = dt.isel(indexer)


print(f"Selected: {AIRXBCAL_005_channels['6']['label']}")
print(dt_subset)
# Out:
# Selected: channel range 937-1103, frequency range 973.82/cm - 1046.20/cm (ozone)
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       HDFEOSVersion:     HDFEOS_V2.12
# │       StructMetadata_0:  GROUP=SwathStructure\n\tGROUP=SWATH_1\n\t\tSwathName=&...
# │       coremetadata:      \nGROUP                  = INVENTORYMETADATA\n  GROUPT...
# │       coremetadata_1:    v5.0.0.0.G07071163024.hdf&quot;, &quot;\n          ftp...
# │       coremetadata_2:              = 1\n        VALUE                = &quot;AM...
# ├── Group: /L1B_AIRS_Cal_Subset
# │   ├── Group: /L1B_AIRS_Cal_Subset/Geolocation_Fields
# │   │       Dimensions:    (_Anonymous54086: 54086)
# │   │       Dimensions without coordinates: _Anonymous54086
# │   │       Data variables:
# │   │           Latitude   (_Anonymous54086) float64 433kB ...
# │   │           Longitude  (_Anonymous54086) float64 433kB ...
# │   │           Time       (_Anonymous54086) float64 433kB ...
# │   ├── Group: /L1B_AIRS_Cal_Subset/Data_Fields
# │   │       Dimensions:             (_Anonymous2378: 2378,
# │   │                                GeoTrack_L1B_AIRS_Cal_Subset: 54086,
# │   │                                IR_Channel_L1B_AIRS_Cal_Subset: 167,
# │   │                                VIS_Channel_L1B_AIRS_Cal_Subset: 3,
# │   │                                _Anonymous54086: 54086,
# │   │                                AMSU_Channel_L1B_AIRS_Cal_Subset: 15)
# │   │       Dimensions without coordinates: _Anonymous2378, GeoTrack_L1B_AIRS_Cal_Subset,
# │   │                                       IR_Channel_L1B_AIRS_Cal_Subset,
# │   │                                       VIS_Channel_L1B_AIRS_Cal_Subset,
# │   │                                       _Anonymous54086,
# │   │                                       AMSU_Channel_L1B_AIRS_Cal_Subset
# │   │       Data variables: (12/30)
# │   │           nominal_freq        (_Anonymous2378) float32 10kB ...
# │   │           radiances           (GeoTrack_L1B_AIRS_Cal_Subset, IR_Channel_L1B_AIRS_Cal_Subset) float32 36MB ...
# │   │           VisMean             (GeoTrack_L1B_AIRS_Cal_Subset, VIS_Channel_L1B_AIRS_Cal_Subset) float32 649kB ...
# │   │           VisStdDev           (GeoTrack_L1B_AIRS_Cal_Subset, VIS_Channel_L1B_AIRS_Cal_Subset) float32 649kB ...
# │   │           satzen              (_Anonymous54086) float32 216kB ...
# │   │           avnsst              (_Anonymous54086) float32 216kB ...
# │   │           ...                  ...
# │   │           solzen              (_Anonymous54086) float32 216kB ...
# │   │           topog               (_Anonymous54086) float32 216kB ...
# │   │           sun_glint_distance  (_Anonymous54086) int16 108kB ...
# │   │           satheight           (_Anonymous54086) float32 216kB ...
# │   │           dust_flag           (_Anonymous54086) int16 108kB ...
# │   │           BT_diff_SO2         (_Anonymous54086) float32 216kB ...
# │   └── Group: /L1B_AIRS_Cal_Subset/Swath_Attributes
# │           Attributes: (12/28)
# │               CF_Version:    CF-973
# │               start_year:    2002
# │               start_month:   8
# │               start_day:     31
# │               start_hour:    0
# │               start_minute:  0
# │               ...            ...
# │               HiCloud_NW:    3633
# │               Random:        6351
# │               Random_DL:     748
# │               Random_DW:     2237
# │               Random_NL:     1306
# │               Random_NW:     2060
# └── Group: /L1B_AIRS_Cal_Subset_Gran_Stats
#     ├── Group: /L1B_AIRS_Cal_Subset_Gran_Stats/Geolocation_Fields
#     ├── Group: /L1B_AIRS_Cal_Subset_Gran_Stats/Data_Fields
#     │       Dimensions:                  (_Anonymous241: 241,
#     │                                     GransProc_L1B_AIRS_Cal_Subset_Gran_Stats: 241,
#     │                                     AMSU_Channels_L1B_AIRS_Cal_Subset_Gran_Stats: 15,
#     │                                     VIS_Channels_L1B_AIRS_Cal_Subset_Gran_Stats: 3,
#     │                                     IR_Channels_L1B_AIRS_Cal_Subset_Gran_Stats: 167)
#     │       Dimensions without coordinates: _Anonymous241,
#     │                                       GransProc_L1B_AIRS_Cal_Subset_Gran_Stats,
#     │                                       AMSU_Channels_L1B_AIRS_Cal_Subset_Gran_Stats,
#     │                                       VIS_Channels_L1B_AIRS_Cal_Subset_Gran_Stats,
#     │                                       IR_Channels_L1B_AIRS_Cal_Subset_Gran_Stats
#     │       Data variables: (12/44)
#     │           center_latitude          (_Anonymous241) float64 2kB ...
#     │           center_longitude         (_Anonymous241) float64 2kB ...
#     │           mean_day_flag            (_Anonymous241) int16 482B ...
#     │           mean_land_flag           (_Anonymous241) int16 482B ...
#     │           cnt_in                   (_Anonymous241) int16 482B ...
#     │           cnt_clear                (_Anonymous241) int16 482B ...
#     │           ...                       ...
#     │           cnt_d_sst1231_gfs_gt_90  (_Anonymous241) int16 482B ...
#     │           cnt_sun_glint            (_Anonymous241) int16 482B ...
#     │           amsu_bt_mean             (GransProc_L1B_AIRS_Cal_Subset_Gran_Stats, AMSU_Channels_L1B_AIRS_Cal_Subset_Gran_Stats) float32 14kB ...
#     │           vis_rad_mean             (GransProc_L1B_AIRS_Cal_Subset_Gran_Stats, VIS_Channels_L1B_AIRS_Cal_Subset_Gran_Stats) float32 3kB ...
#     │           CalChanSummary           (GransProc_L1B_AIRS_Cal_Subset_Gran_Stats, IR_Channels_L1B_AIRS_Cal_Subset_Gran_Stats) float32 161kB ...
#     │           NeN                      (GransProc_L1B_AIRS_Cal_Subset_Gran_Stats, IR_Channels_L1B_AIRS_Cal_Subset_Gran_Stats) float32 161kB ...
#     └── Group: /L1B_AIRS_Cal_Subset_Gran_Stats/Swath_Attributes
