# %% [markdown]
# # How to Find and Plot a timeseries Level 2 Data from Multiple Granules using Python

# %% [markdown]
# ## Overview
#
# Level 2 data from Low Earth Orbit (LEO) satellites are often organized into \"granules\" that contain spatial sets of data that may not match up with the region of interest.  If the region is smaller than the granule, the user can create a spatial subset.  If the region spans mulitple granules, each granule may be plotted individually, or the data can be aggregated and plotted at once.  The How-to will do both of these by showing users how to find the granules in the region of interest and then subset and aggregate the variables over a long time series to create a timeseries plot over a given location.<br>
#
# This program will download the relevant OCO-2 Level 2 Lite file data required to make a time series plot.  It could take a long time to download all of the files for a long time series but if the program is run a second time it will not download the files again if they are still in the local data directory.
#
# An alternative to downloading the full files would be to use the GES DISC subsetter or OPeNDAP to only download the data in the region of interest as described in the following How-Tos.  Or this program could be run in the cloud.  A function called "get_CMRgranurls" described in this How-to will return the data, OPeNDAP, and S3 urls in the region of interest.:
# https://disc.gsfc.nasa.gov/information/howto?title=How%20to%20Use%20the%20Web%20Services%20API%20for%20Subsetting (using the GES DISC subsetter)
# https://disc.gsfc.nasa.gov/information/howto?keywords=opendap&title=How%20to%20download%20a%20spatial%20and%20variable%20subset%20of%20Level%201B%20data%20using%20OPeNDAP (using OPeNDAP)
#
# Citation for the OCO-2 Lite file data used in this How-To document:
# OCO-2/OCO-3 Science Team, Vivienne Payne, Abhishek Chatterjee (2022), OCO-2 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing V11.1r, Greenbelt, MD, USA, Goddard Earth Sciences Data and Information Services Center (GES DISC), Accessed: [Data Access Date], 10.5067/8E4VLCK16O6Q
#
# The OCO-2 data in the How-to Document are also compared to the CO2 record from Scripps:
# C. D. Keeling, S. C. Piper, R. B. Bacastow, M. Wahlen, T. P. Whorf, M. Heimann, and H. A. Meijer, Exchanges of atmospheric CO2 and 13CO2 with the terrestrial biosphere and oceans from 1978 to 2000. I. Global aspects, SIO Reference Series, No. 01-06, Scripps Institution of Oceanography, San Diego, 88 pages, 2001.
#
# ---
#
# This example code is written in Python 3.9 and requires these libraries and files: <br>
# - numpy<br>
# - requests<br>
# - netCDF <br>
# - matplotlib<br>
# - cartopy  <br>
# - netrc file with valid Earthdata Login credentials ([How to Generate Earthdata Prerequisite Files](https://disc.gsfc.nasa.gov/information/howto?keywords=prerequisite&title=How%20to%20Generate%20Earthdata%20Prerequisite%20Files))<br>
# - Approval to access the GES DISC archives with your Earthdata credentials (https://disc.gsfc.nasa.gov/earthdata-login)<br>
# - wget (https://www.gnu.org/software/wget/)<br>
# <br>
# *Note: If the files to be aggregated are not in netCDF format, a different library (e.g. Xarray) will have to be used.*

# %% [markdown]
# ### 1. Import Libraries

# %%
import glob
import numpy as np
import netCDF4
from netCDF4 import Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import os
import requests
from cmr import CollectionQuery, GranuleQuery, ToolQuery, ServiceQuery, VariableQuery
import datetime
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import csv
import pdb
import pandas as pd
import time
from spacepy.time import Ticktock
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ### 2. Define funtions used in this tutorial

# %%
def get_CMRgranurls(ShortName,VersionID,start_time,end_time,lon=None,lat=None,rad_km=None):
    """
    This program returns a dictionary with lists of data, opendap, and S3 urls.  If lon, lat, and radius are given, this function will search for all granules defined by that circle.  If lon and lat are 2 element lists, then this function will search for all granules defined by a bounding box.  If lon, lat, and radius_km are not given this function will search for all granules between the input start_time and end_time.  This function uses python-cmr to get the urls but it does not require prior knowledge of how many urls will be returned.
INPUTS
    "ShortName" the data set shortname
    "VersionID" the version ID of the product
    "start_time"  start time in utc.  The following is appended to the date: "T00:00:00Z.
    "end_time"  start time in utc The following is appended to the date: "T00:00:00Z, thus the end date is not actualy included in the results.
    "lon", "lat", "rad_km" (optional) will search within a radius or bounding box near a given location. If a radius or bounding box is not given, this function will return all granules within the input timerange.  
    OUTPUTS
    "urls" A dictionary with urls for the data, opendap, and s3 urls.  It also returns the start_time and end_time that were inputs into the program.
     
EXAMPLE
    Find all of the AIRX2RET granules within 30 km of  New Orleans
    > from opensearchtools.get_MOSurls import get_MOSurls
    > urls = get_CMRgranurls('AIRX2RET.006','2002.09.01','2016.01.01',lon=-90.0667,lat=29.95, rad_km=30.0)
    If a radius is not specified it will return all of the granules on the days in the search period.  For     example, following will return 241 granules.  The 1 extra if from 2002.08.31 part of which is on 2002.09.01
    > 
    > urls = get_CMRgranurls('AIRX2RET.006','2002.09.01','2002.09.02')
    HISTORY
    Created by Thomas Hearty,  March 14, 2016 
    """
    start_time = start_time.replace('.','-')
    end_time = end_time.replace('.','-')
    if len(start_time) == 10:
        start_time = start_time+"T00:00:00Z"
        end_time = end_time+"T00:00:00Z"

    # create a list of start and end times strings
    start_dt = datetime.datetime.fromtimestamp(time.mktime(time.strptime(start_time,"%Y-%m-%dT%H:%M:%SZ")))
    end_dt = datetime.datetime.fromtimestamp(time.mktime(time.strptime(end_time,"%Y-%m-%dT%H:%M:%SZ")))
    
    deltatime = end_dt - start_dt
    start_times = [start_time]
    end_times = []
    timeincrement = datetime.timedelta(7)
    while deltatime > timeincrement:
        old_start_dt = start_dt
        start_dt = old_start_dt+timeincrement
        end_times.append(start_dt.strftime("%Y-%m-%dT%H:%M:%SZ"))
        start_times.append(end_times[-1])
        deltatime = end_dt - start_dt
    end_times.append(end_time)
 
    s3_urls = []
    opendap_urls = []
    data_urls = []
    for start_time_seg,end_time_seg in zip(start_times,end_times):
        api = GranuleQuery()

        # there are three types of searches that I can do.  1) global, 2) bounding box, 3) point radius
        if rad_km is None and lon is None and lat is None: # this is a global search
            granules = api.short_name(ShortName).version(VersionID).temporal(start_time_seg,end_time_seg).get(1000000) 
        elif rad_km is None and len(lon) == 2 and len(lat) == 2:
            granules = api.short_name(ShortName).version(VersionID).temporal(start_time_seg,end_time_seg).bounding_box(lon[0],lat[0],lon[1],lat[1]).get(1000000)
        else: # for now I will assume it is a circle
            granules = api.short_name(ShortName).version(VersionID).temporal(start_time_seg,end_time_seg).circle(lon,lat,rad_km*1000.).get(1000000)
        
        for granule in granules:
            for link in granule.get('links',[]):
                if 'rel' in link and 'href' in link and 'inherited' not in link:
                    if 'http://esipfed.org/ns/fedsearch/1.1/s3#' in link['rel']: # It's an s3 url
                        s3_urls.append(link['href'])
                    if 'http://esipfed.org/ns/fedsearch/1.1/service#' in link['rel'] and 'opendap' in link['href']: # It's an opendap link
                        opendap_urls.append(link['href'])
                    if 'http://esipfed.org/ns/fedsearch/1.1/data#' in link['rel']: # It's a data url
                        data_urls.append(link['href'])
        
        # Get just the URLs (identified by 'via S3' in the link title)
        ###s3_urls_seg = [link['href'] for link in gran_links if 'http://esipfed.org/ns/fedsearch/1.1/s3#' in link['rel']]

        # Get just the URLs (identified by 'OPENDAP location for the granule' in the link title)
        ###opendap_urls_seg = [link['href'] for link in gran_links if 'OPENDAP location for the granule' in link['title']]

        # Finally, get just the URLs (identified by 'Download' in the link title)
        ###data_urls_seg = [link['href'] for link in gran_links if 'http://esipfed.org/ns/fedsearch/1.1/data#' in link['rel']]
            
    # we did this already, but lets do it again because the same file can appear in multiple segments.
    s3_urls = list(set(s3_urls)) # makes them unique and sorts them
    opendap_urls = list(set(opendap_urls)) # makes them unique and sorts them
    data_urls = list(set(data_urls)) # makes them unique and sorts them
    s3_urls.sort() # this will probably put them in chronological order but it must be verified.
    opendap_urls.sort() # this will probably put them in chronological order but it must be verified.
    data_urls.sort() # this will probably put them in chronological order but it must be verified.
    urls = {'s3':s3_urls,'opendap':opendap_urls,'data':data_urls}
    
    return urls,start_time,end_time

# %%
def dist_km(lon1_deg,lat1_deg,lon2_deg,lat2_deg):
    """
PURPOSE
    This function calculates the distance in km 
    between to points on the surface of the earth given the
    longitude and latitude of the 2 points in degrees and the assumption
    that the radius of the earth is 6371 km.
HISTORY
    Created by Thomas Hearty March 14, 2016
    """
    Rearth = 6371.0
    lat1_rad = np.radians(lat1_deg)
    lon1_rad = np.radians(lon1_deg)
    lat2_rad = np.radians(lat2_deg)
    lon2_rad = np.radians(lon2_deg)
    dist_rad = np.arccos(np.cos(lat1_rad) * np.cos(lat2_rad) * np.cos(lon1_rad - lon2_rad) + np.sin(lat1_rad) * np.sin(lat2_rad))
    dist_km = Rearth * dist_rad
    return dist_km

# %%
def list2txt(inlist,outfile):
    '''
A simple program to write a list of strings to a text file
    '''
    f = open(outfile,'w')
    for line in inlist:
        f.write(line+'\n')
    f.close()

# %%
# these functions are used to download a list of files.
def download_file(url, datadir):
    url = url.strip()
    filename = os.path.join(datadir, os.path.basename(url))
    if not os.path.exists(filename):
        response = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(response.content)

def download_files(urls, datadir):
    # Read the URLs from the file
    with open(urls, 'r') as file:
        dataurls = file.readlines()
    # Use ThreadPoolExecutor to download files concurrently
    with ThreadPoolExecutor() as executor:
        # Submit download tasks to the executor
        futures = [executor.submit(download_file, url, datadir) for url in dataurls]
        # Optionally, wait for all tasks to complete
        for future in futures:
            future.result()

# %% [markdown]
# ### 3. Define the dataset and search criteria
# The ShortName and VersionID uniquely define the dataset to search.

# %%
ShortName = "OCO2_L2_Lite_FP"
VersionID = '11.1r'

# %% [markdown]
# This example will search for all OCO-2 observations within 100 km radius around Mauna Loa but this could be a set of locations.

# %%
title_string = "Mauna Loa"
pointlon = -155.57
pointlat = 19.536
pointradius = 100 # km
time_start = datetime.datetime(2017,1,1)
time_end = datetime.datetime(2018,1,1)

# %% [markdown]
# Include a point and radius of the search in the output filename.

# %%
datacircle_string = "{:8.3f},{:8.3f},{:8f}".format(pointlon,pointlat,pointradius).replace(' ','')
aggfile = title_string.replace(' ','')+'_'+ShortName+'.'+VersionID+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_Circle'+datacircle_string+'.nc'

# %% [markdown]
# ### 4. Use get_CMRgranurls to get the data urls and download the files

# %%
# this can take a few minutes for a long time series.
urls,out_time_start,out_time_end = get_CMRgranurls(ShortName,VersionID,time_start.strftime('%Y.%m.%d'),time_end.strftime('%Y.%m.%d'),lon=pointlon,lat=pointlat,rad_km=pointradius)

# %%
# Create a directory based on the ShortName and VersionID to which the original data files can be downloaded
data_rootdir = './data/' 
datadir = data_rootdir +ShortName + '.' + VersionID # this is where I will download the files
if os.path.exists(datadir) is False:
    os.makedirs(datadir)

# %%
# save the list of urls to a text file that can be used by requests.
list2txt(urls['data'],'dataurls.txt')

# %%
# Download granules in parallel using the functions we defined earlier
download_files('dataurls.txt',datadir)

# %% [markdown]
# change the data urls to local path for the local files.

# %%
# save the local filesnames to a text file
localdatafiles = []
for  url in urls['data']:
    localdatafiles.append(datadir + '/' + os.path.basename(url))

list2txt(localdatafiles,'oco2L2local.txt')

# %% [markdown]
# ### 5. Aggregate the data and save in a netCDF file
# The following block of code reads the names of the local netCDF files and aggregates the data in the region of interest.

# %%
# names of the coordinate variables
lon_var = 'longitude'
lat_var = 'latitude'
time_var = 'time'
coordinate_vars = [lon_var,lat_var,time_var]

# names of the science variables
science_vars = ['xco2','xco2_quality_flag','Sounding/land_fraction','solar_zenith_angle']

# %%
# aggregated the variables if the aggregated file does not already exist.
if os.path.exists(aggfile) is True:
    # Don't create the file if it already exists
    print(aggfile+' already exists.')    
else:
    # I'll create it.        
    N=0

    # put all coordinate and science variables intothe following dictionary
    plot_dic = {}
    for var in coordinate_vars+science_vars:
        plot_dic[var] = np.array([])
    for ifile,file in enumerate(localdatafiles):
        print('Reading '+file)
        fid = netCDF4.Dataset(file ,mode='r',format='NETCDF4')
        longitude = fid.variables[lon_var][:]
        latitude = fid.variables[lat_var][:]
        dist = dist_km(pointlon,pointlat,longitude,latitude)
        validdata = dist <= pointradius
        if dist[validdata].size > 0: # there is some data within the radius
            # Now I'll fill the plot_dic with the relevant coordinate and science data
            for var in plot_dic.keys():
                plot_dic[var] = np.append(plot_dic[var],fid[var][:].data[validdata])

    # now write out all of the variables so I don't have to aggregate it again if I run the program again
    # write the aggregated variables to a netcdf file.
    ncfile = Dataset(aggfile,mode='w',format='NETCDF4')
    # create a time dimension
    time_dim = ncfile.createDimension('time', None)
    for var in plot_dic.keys():
        tmpvar = ncfile.createVariable(var, np.float64, ('time',))
        tmpvar[:] = plot_dic[var]
    ncfile.close()
# Out:
# MaunaLoa_OCO2_L2_Lite_FP.11.1r_20170101to20180101_Circle-155.570,19.536,100.000000.nc already exists.

# %% [markdown]
# ### 6. Read the aggregated file

# %%
fid = netCDF4.Dataset(aggfile ,mode='r',format='NETCDF4')
plot_dic = {} #

for key in fid.variables.keys():
    plot_dic[key] = fid.variables[key][:].data
for group in fid.groups.keys() : # see if any data are in groups
    for key in fid.groups[group].variables.keys():
        plot_dic[group+'/'+key] =  fid.groups[group].variables[key][:].data # I'm not going any deeper than this for now.

# %% [markdown]
# ### 7. plot XCO2 on a map

# %%
# although we will plot all of the values set the limits based on the good data
ocogood = plot_dic['xco2_quality_flag'] == 0
lowerlimit = np.min(plot_dic['xco2'][ocogood])
upperlimit = np.max(plot_dic['xco2'][ocogood])

mapprojection = ccrs.PlateCarree()
fig = plt.figure()
ax = plt.axes(projection=mapprojection,label='allmap')
ax.coastlines()
gl=ax.gridlines(crs=mapprojection, draw_labels=True,linewidth=0.75, color='black')
ncolors=10
cmap=plt.cm.rainbow
bounds = np.linspace(lowerlimit,upperlimit,ncolors+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
c=plt.scatter(plot_dic['longitude'],plot_dic['latitude'],c=plot_dic['xco2'], cmap=cmap, norm=norm, edgecolor='black', linewidth=0)
plt.colorbar(ax=ax, orientation="vertical", pad=0.110, spacing='proportional', ticks=bounds, boundaries=bounds, format='%7.2f', extend = "both")
x=plt.plot([pointlon],[pointlat],marker='x',color='k',ms=15,mew=2)
ax.set_title(title_string)
# Out:
# Text(0.5, 1.0, 'Mauna Loa')

# %%
# Save the figure to show your friends
filename = title_string.replace(' ','')+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_allmap.png'
print('Save '+filename)
fig.savefig(filename)
ax.cla()
fig.clf()
# Out:
# Save MaunaLoa_20170101to20180101_allmap.png

# %%
# Let's make the same figure but only look at the good quality data.

fig = plt.figure()
ax = plt.axes(projection=mapprojection,label='goodmap')
ax.coastlines()
gl=ax.gridlines(crs=mapprojection, draw_labels=True,linewidth=0.75, color='black')

ncolors=10
cmap=plt.cm.rainbow
bounds = np.linspace(lowerlimit,upperlimit,ncolors+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
c=plt.scatter(plot_dic['longitude'][ocogood],plot_dic['latitude'][ocogood],c=plot_dic['xco2'][ocogood], cmap=cmap, norm=norm, edgecolor='black', linewidth=0)
plt.colorbar(ax=ax, orientation="vertical", pad=0.110, spacing='proportional', ticks=bounds, boundaries=bounds, format='%7.2f', extend = "both")
x=plt.plot([pointlon],[pointlat],marker='x',color='k',ms=15,mew=2)
ax.set_title(title_string)
# Out:
# Text(0.5, 1.0, 'Mauna Loa')

# %%
filename = title_string.replace(' ','')+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_goodmap.png'
print(filename)
fig.savefig(filename)
ax.cla()
fig.clf()print(aggfile)
# Out:
# MaunaLoa_20170101to20180101_goodmap.png

# %% [markdown]
# ### 8. Now plot a time series of the good data from the above figure
# The OCO-2 files have time measured in seconds since 1970-1-1 but plot_date requires a UTC datetime array.

# %%
#We can use Ticktock from spacepy to convert the TAI time in seconds since 1970-01-01 to a UTC datetime array.
t = Ticktock(plot_dic['time'][:], 'UNX')
oco2l2_utc = t.UTC

# %%
fig, ax = plt.subplots()
ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2',color='k',marker='o')
ax.set_ylim([np.floor(lowerlimit)-5,np.ceil(upperlimit)+5])
ax.set_ylabel('xCO2 [ppm]')
ax.fmt_xdata = DateFormatter('%Y-%m-%d')
ax.grid(True)
fig.autofmt_xdate()
ax.set_title(title_string)
# Out:
# /tmp/ipykernel_2167406/2946289606.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2',color='k',marker='o')
# Text(0.5, 1.0, 'Mauna Loa')

# %%
filename = title_string.replace(' ','')+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_xco2_ts_oco2.png'
print(filename)
fig.savefig(filename)
ax.cla()
fig.clf()
# Out:
# MaunaLoa_20170101to20180101_xco2_ts_oco2.png

# %% [markdown]
# ### 9. Finally we show how to compare the OCO-2 time series plot with daily in-situ measurements from Mauna Loa

# %%
# We can download and read the Mauna Loa data
url = "https://scrippsco2.ucsd.edu/assets/data/atmospheric/stations/in_situ_co2/daily/daily_in_situ_co2_mlo.csv"
filename = url.split("/")[-1]  # Extract the filename from the URL

response = requests.get(url)

if response.status_code == 200:  # Check if the request was successful
    with open(filename, 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")

mlo_insitu_daily = pd.read_csv('daily_in_situ_co2_mlo.csv',skiprows=13,names=['Yr','Mn','Dy','CO2','NB','scale','sta'])

# %%
# Make a datetime array for the times of the Mauna Loa Observations
mlo_insitu_utc = []
for i in range(len(mlo_insitu_daily['Dy'])):
    mlo_insitu_utc.append(datetime.datetime(mlo_insitu_daily['Yr'][i],mlo_insitu_daily['Mn'][i],mlo_insitu_daily['Dy'][i]))
# convert the list of dates to an array.
mlo_insitu_utc = np.array(mlo_insitu_utc)

# %%
# now convert the Mauna Loa CO2 observations to an array after converting all of the values to a floating point number.
mlo_insitu_xco2 = np.array(mlo_insitu_daily['CO2'])
for i, xco2 in enumerate(mlo_insitu_xco2):
    if 'NaN' in xco2:
        mlo_insitu_xco2[i]=-999999.0
    else:
        mlo_insitu_xco2[i] = float(xco2)
mlo_insitu_xco2 = np.array(mlo_insitu_xco2)

# %%
# for this figure we can separate the OCO-2 measurements over water and over land by using the land_fraction variable to see if there are any differences.
ocogoodland = np.logical_and(ocogood,plot_dic['Sounding/land_fraction'] > 0)
ocogoodwater = np.logical_and(ocogood,plot_dic['Sounding/land_fraction'] ==0)

mlo_valid = mlo_insitu_xco2 != -999999.
# OCO-2 data with Daily In-situ
fig, ax = plt.subplots()
ax.plot_date(mlo_insitu_utc[mlo_valid], mlo_insitu_xco2[mlo_valid], label='In-situ',color='k',marker='x',ms=8)
ax.plot_date(oco2l2_utc[ocogoodland], plot_dic['xco2'][ocogoodland],label='OCO-2 L2 Land',color='r',marker='o',ms=8)
ax.plot_date(oco2l2_utc[ocogoodwater], plot_dic['xco2'][ocogoodwater],label='OCO-2 L2 Water',color='b',marker='o',ms=5)
ax.set_xlim([time_start,time_end])
ax.set_ylim([np.floor(lowerlimit)-5,np.ceil(upperlimit)+5])
ax.set_ylabel('xCO2 [ppm]')
ax.fmt_xdata = DateFormatter('%Y-%m-%d')
ax.grid(True)
fig.autofmt_xdate()
ax.set_title(title_string)
plt.legend()
# Out:
# /tmp/ipykernel_2167406/1574962966.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mlo_insitu_utc[mlo_valid], mlo_insitu_xco2[mlo_valid], label='In-situ',color='k',marker='x',ms=8)
# /tmp/ipykernel_2167406/1574962966.py:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc[ocogoodland], plot_dic['xco2'][ocogoodland],label='OCO-2 L2 Land',color='r',marker='o',ms=8)
# /tmp/ipykernel_2167406/1574962966.py:10: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc[ocogoodwater], plot_dic['xco2'][ocogoodwater],label='OCO-2 L2 Water',color='b',marker='o',ms=5)

# %%
# Let's save a figure to show our friends that the OCO-2 observations over land and water both match the station measurements well but the observations over land seem to have a larger dispersion.
filename = title_string.replace(' ','')+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_xco2_ts_oco2_insitu.png'
print(filename)
fig.savefig(filename)
ax.cla()
fig.clf()
# Out:
# MaunaLoa_20170101to20180101_xco2_ts_oco2_insitu.png

# %% [markdown]
# ### 10. Now we can repeat this process for another region.   The example below shows how to make similar time series of OCO-2 data within 100 km of the Caltech TCCON station.

# %%
# specify the dataset ShortName and VerisonID
ShortName = "OCO2_L2_Lite_FP"
VersionID = '11.1r'

# define the search criteria
title_string = "Caltech"
pointlon = -118.13
pointlat = 34.140
pointradius = 100 # km
time_start = datetime.datetime(2017,1,1)
time_end = datetime.datetime(2018,1,1)

# write a point radius string and output filename
datacircle_string = "{:8.3f},{:8.3f},{:8f}".format(pointlon,pointlat,pointradius).replace(' ','')
aggfile = title_string.replace(' ','')+'_'+ShortName+'.'+VersionID+'_'+time_start.strftime('%Y%m%d')+'to'+time_end.strftime('%Y%m%d')+'_Circle'+datacircle_string+'.nc'

# %%
# this can take a few minutes for a long time series.
urls,out_time_start,out_time_end = get_CMRgranurls(ShortName,VersionID,time_start.strftime('%Y.%m.%d'),time_end.strftime('%Y.%m.%d'),lon=pointlon,lat=pointlat,rad_km=pointradius)

# %%
# Create a directory based on the ShortName and VersionID to which the original data files can be downloaded
data_rootdir = './data/' 
datadir = data_rootdir +ShortName + '.' + VersionID # this is where I will download the files
if os.path.exists(datadir) is False:
    os.makedirs(datadir)

# save the list of urls to a text file that can be used by requests.
list2txt(urls['data'],'dataurls.txt')

# download the files
download_files('dataurls.txt',datadir)

# save the local filesnames to a text file
localdatafiles = []
for  url in urls['data']:
    localdatafiles.append(datadir + '/' + os.path.basename(url))

list2txt(localdatafiles,'oco2L2local.txt')

# %%
# Now we will aggregate the data for the time series and save it in a file

# names of the coordinate variables
lon_var = 'longitude'
lat_var = 'latitude'
time_var = 'time'print(aggfile)
coordinate_vars = [lon_var,lat_var,time_var]

# names of the science variables
science_vars = ['xco2','xco2_quality_flag','Sounding/land_fraction','solar_zenith_angle']

# aggregated the variables if the aggregated file does not already exist.
if os.path.exists(aggfile) is True:
    # Don't create the file if it already exists
    print(aggfile+' already exists.')    
else:
    # I'll create it.        
    N=0

    # put all coordinate and science variables intothe following dictionary
    plot_dic = {}
    for var in coordinate_vars+science_vars:
        plot_dic[var] = np.array([])
    for ifile,file in enumerate(localdatafiles):
        print('Reading '+file)
        fid = netCDF4.Dataset(file ,mode='r',format='NETCDF4')
        longitude = fid.variables[lon_var][:]
        latitude = fid.variables[lat_var][:]
        dist = dist_km(pointlon,pointlat,longitude,latitude)
        validdata = dist <= pointradius
        if dist[validdata].size > 0: # there is some data within the radius
            # Now I'll fill the plot_dic with the relevant coordinate and science data
            for var in plot_dic.keys():
                plot_dic[var] = np.append(plot_dic[var],fid[var][:].data[validdata])

    # now write out all of the variables so I don't have to aggregate it again if I run the program again
    # write the aggregated variables to a netcdf file.
    ncfile = Dataset(aggfile,mode='w',format='NETCDF4')
    # create a time dimension
    time_dim = ncfile.createDimension('time', None)
    for var in plot_dic.keys():
        tmpvar = ncfile.createVariable(var, np.float64, ('time',))
        tmpvar[:] = plot_dic[var]
    ncfile.close()
# Out:
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170101_B11100Ar_230601162724s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170102_B11100Ar_230601162755s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170103_B11100Ar_230601162825s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170104_B11100Ar_230601162855s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170105_B11100Ar_230601162926s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170106_B11100Ar_230601163138s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170107_B11100Ar_230601163138s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170108_B11100Ar_230601163158s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170109_B11100Ar_230601163327s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170110_B11100Ar_230601163354s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170111_B11100Ar_230601163623s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170112_B11100Ar_230601163632s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170113_B11100Ar_230601163633s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170114_B11100Ar_230601163739s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170115_B11100Ar_230601163815s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170116_B11100Ar_230601164045s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170117_B11100Ar_230601164054s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170118_B11100Ar_230601164055s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170119_B11100Ar_230601164209s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170120_B11100Ar_230601164237s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170121_B11100Ar_230601164512s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170122_B11100Ar_230601164524s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170123_B11100Ar_230601164526s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170124_B11100Ar_230601164619s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170125_B11100Ar_230601164707s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170126_B11100Ar_230601164933s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170127_B11100Ar_230601164933s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170128_B11100Ar_230601164942s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170129_B11100Ar_230601165106s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170130_B11100Ar_230601165119s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170131_B11100Ar_230601165353s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170201_B11100Ar_230601165411s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170202_B11100Ar_230601165413s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170203_B11100Ar_230601165533s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170204_B11100Ar_230601165601s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170205_B11100Ar_230601165825s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170206_B11100Ar_230601165841s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170207_B11100Ar_230601165846s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170208_B11100Ar_230601170027s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170209_B11100Ar_230601170027s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170210_B11100Ar_230601170237s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170211_B11100Ar_230601170313s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170212_B11100Ar_230601170335s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170213_B11100Ar_230601170518s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170214_B11100Ar_230601170537s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170215_B11100Ar_230601170740s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170216_B11100Ar_230601170756s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170217_B11100Ar_230601170818s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170218_B11100Ar_230601170958s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170219_B11100Ar_230601171019s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170220_B11100Ar_230601171209s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170221_B11100Ar_230601171257s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170228_B11100Ar_230601171308s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170301_B11100Ar_230601171436s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170302_B11100Ar_230601171439s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170303_B11100Ar_230601171512s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170304_B11100Ar_230601171649s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170305_B11100Ar_230601171702s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170306_B11100Ar_230601171931s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170307_B11100Ar_230601171932s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170308_B11100Ar_230601171949s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170309_B11100Ar_230601172142s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170310_B11100Ar_230601172158s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170311_B11100Ar_230601172433s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170312_B11100Ar_230601172437s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170313_B11100Ar_230601172448s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170314_B11100Ar_230601172604s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170315_B11100Ar_230601172635s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170316_B11100Ar_230601172900s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170317_B11100Ar_230601172915s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170318_B11100Ar_230601173009s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170319_B11100Ar_230601173108s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170320_B11100Ar_230601173142s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170321_B11100Ar_230601173343s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170322_B11100Ar_230601173346s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170323_B11100Ar_230601173431s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170324_B11100Ar_230601173528s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170325_B11100Ar_230601173621s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170326_B11100Ar_230601173824s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170327_B11100Ar_230601173830s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170328_B11100Ar_230601173849s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170329_B11100Ar_230601173926s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170330_B11100Ar_230601174049s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170331_B11100Ar_230601174250s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170401_B11100Ar_230601174253s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170402_B11100Ar_230601174336s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170403_B11100Ar_230601174424s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170404_B11100Ar_230601174534s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170405_B11100Ar_230601174743s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170406_B11100Ar_230601174801s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170407_B11100Ar_230601174814s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170408_B11100Ar_230601174913s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170409_B11100Ar_230601174956s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170410_B11100Ar_230601175225s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170411_B11100Ar_230601175240s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170412_B11100Ar_230601175302s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170413_B11100Ar_230601175356s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170414_B11100Ar_230601175417s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170415_B11100Ar_230601175646s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170416_B11100Ar_230601175723s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170417_B11100Ar_230601175727s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170418_B11100Ar_230601175839s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170419_B11100Ar_230601175843s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170420_B11100Ar_230601180134s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170421_B11100Ar_230601180137s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170422_B11100Ar_230601180146s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170423_B11100Ar_230601180257s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170424_B11100Ar_230601180322s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170425_B11100Ar_230601180600s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170426_B11100Ar_230601180602s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170427_B11100Ar_230601180648s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170428_B11100Ar_230601180722s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170429_B11100Ar_230601180749s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170430_B11100Ar_230601181002s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170501_B11100Ar_230601181041s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170502_B11100Ar_230601181057s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170503_B11100Ar_230601181200s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170504_B11100Ar_230601181215s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170505_B11100Ar_230601181445s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170506_B11100Ar_230601181452s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170507_B11100Ar_230601181531s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170508_B11100Ar_230601181652s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170509_B11100Ar_230601181723s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170510_B11100Ar_230601181905s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170511_B11100Ar_230601181910s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170512_B11100Ar_230601182022s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170513_B11100Ar_230601182105s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170514_B11100Ar_230601182134s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170515_B11100Ar_230601182324s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170516_B11100Ar_230601182332s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170517_B11100Ar_230601182511s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170518_B11100Ar_230601182512s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170519_B11100Ar_230601182614s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170520_B11100Ar_230601182751s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170521_B11100Ar_230601182817s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170522_B11100Ar_230601182917s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170523_B11100Ar_230601182936s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170524_B11100Ar_230601182959s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170525_B11100Ar_230601183113s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170526_B11100Ar_230601183309s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170527_B11100Ar_230601183355s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170528_B11100Ar_230601183419s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170529_B11100Ar_230601183504s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170530_B11100Ar_230601183615s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170531_B11100Ar_230601183800s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170601_B11100Ar_230601183850s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170602_B11100Ar_230601183922s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170603_B11100Ar_230601183955s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170604_B11100Ar_230601184054s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170605_B11100Ar_230601184216s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170606_B11100Ar_230601184402s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170607_B11100Ar_230601184419s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170608_B11100Ar_230601184435s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170609_B11100Ar_230601184551s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170610_B11100Ar_230601184716s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170611_B11100Ar_230601184904s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170612_B11100Ar_230601184911s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170613_B11100Ar_230601184932s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170614_B11100Ar_230601185045s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170615_B11100Ar_230601185206s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170616_B11100Ar_230601185402s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170617_B11100Ar_230601185417s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170618_B11100Ar_230601185418s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170619_B11100Ar_230601185531s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170620_B11100Ar_230601185658s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170621_B11100Ar_230601185840s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170622_B11100Ar_230601185907s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170623_B11100Ar_230601185938s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170624_B11100Ar_230601190028s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170625_B11100Ar_230601190126s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170626_B11100Ar_230601190333s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170627_B11100Ar_230601190417s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170628_B11100Ar_230601190427s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170629_B11100Ar_230601190501s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170630_B11100Ar_230601190632s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170701_B11100Ar_230601215313s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170702_B11100Ar_230601215343s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170703_B11100Ar_230601215414s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170704_B11100Ar_230601215444s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170705_B11100Ar_230601215514s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170706_B11100Ar_230601215838s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170707_B11100Ar_230601215838s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170708_B11100Ar_230601215919s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170709_B11100Ar_230601215947s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170710_B11100Ar_230601220022s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170711_B11100Ar_230601220352s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170712_B11100Ar_230601220416s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170713_B11100Ar_230601220431s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170714_B11100Ar_230601220433s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170715_B11100Ar_230601220522s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170716_B11100Ar_230601220856s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170717_B11100Ar_230601220918s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170718_B11100Ar_230601220950s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170719_B11100Ar_230601221002s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170720_B11100Ar_230601221036s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170721_B11100Ar_230601221328s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170722_B11100Ar_230601221415s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170723_B11100Ar_230601221447s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170724_B11100Ar_230601221540s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170725_B11100Ar_230601221601s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170726_B11100Ar_230601221828s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170727_B11100Ar_230601221913s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170728_B11100Ar_230601221935s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170729_B11100Ar_230601222048s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170730_B11100Ar_230601222057s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170919_B11100Ar_230601222124s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170920_B11100Ar_230601222311s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170921_B11100Ar_230601222343s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170922_B11100Ar_230601222404s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170923_B11100Ar_230601222456s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170924_B11100Ar_230601222521s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170925_B11100Ar_230601222611s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170926_B11100Ar_230601222720s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170927_B11100Ar_230601222814s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170928_B11100Ar_230601222926s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170929_B11100Ar_230601222939s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_170930_B11100Ar_230601222944s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171001_B11100Ar_230601223000s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171002_B11100Ar_230601223052s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171003_B11100Ar_230601223106s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171004_B11100Ar_230601223217s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171005_B11100Ar_230601223332s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171006_B11100Ar_230601223408s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171007_B11100Ar_230601223435s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171008_B11100Ar_230601223453s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171009_B11100Ar_230601223458s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171010_B11100Ar_230601223557s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171011_B11100Ar_230601223630s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171012_B11100Ar_230601223839s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171013_B11100Ar_230601223943s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171014_B11100Ar_230601223944s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171015_B11100Ar_230601223955s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171016_B11100Ar_230601223956s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171017_B11100Ar_230601224047s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171018_B11100Ar_230601224216s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171019_B11100Ar_230601224315s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171020_B11100Ar_230601224504s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171021_B11100Ar_230601224511s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171022_B11100Ar_230601224523s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171023_B11100Ar_230601224542s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171024_B11100Ar_230601224631s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171025_B11100Ar_230601224702s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171026_B11100Ar_230601224934s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171027_B11100Ar_230601224941s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171028_B11100Ar_230601225042s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171029_B11100Ar_230601225052s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171030_B11100Ar_230601225059s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171104_B11100Ar_230601225134s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171105_B11100Ar_230601225222s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171106_B11100Ar_230601225339s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171107_B11100Ar_230601225509s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171108_B11100Ar_230601225610s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171109_B11100Ar_230601225626s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171110_B11100Ar_230601225723s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171111_B11100Ar_230601225831s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171112_B11100Ar_230601225953s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171113_B11100Ar_230601230113s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171114_B11100Ar_230601230128s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171115_B11100Ar_230601230208s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171116_B11100Ar_230601230403s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171117_B11100Ar_230601230455s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171118_B11100Ar_230601230600s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171119_B11100Ar_230601230600s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171120_B11100Ar_230601230703s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171121_B11100Ar_230601230856s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171122_B11100Ar_230601231001s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171123_B11100Ar_230601231037s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171124_B11100Ar_230601231044s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171125_B11100Ar_230601231120s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171126_B11100Ar_230601231311s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171127_B11100Ar_230601231444s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171128_B11100Ar_230601231507s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171129_B11100Ar_230601231531s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171130_B11100Ar_230601231554s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171201_B11100Ar_230601231757s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171202_B11100Ar_230601231924s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171203_B11100Ar_230601231926s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171204_B11100Ar_230601232012s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171205_B11100Ar_230601232046s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171206_B11100Ar_230601232238s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171207_B11100Ar_230601232421s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171208_B11100Ar_230601232431s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171209_B11100Ar_230601232435s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171210_B11100Ar_230601232505s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171211_B11100Ar_230601232712s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171212_B11100Ar_230601232850s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171213_B11100Ar_230601232853s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171214_B11100Ar_230601232915s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171215_B11100Ar_230601232940s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171216_B11100Ar_230601233128s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171217_B11100Ar_230601233321s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171218_B11100Ar_230601233335s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171219_B11100Ar_230601233347s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171220_B11100Ar_230601233350s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171221_B11100Ar_230601233536s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171222_B11100Ar_230601233639s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171223_B11100Ar_230601233745s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171224_B11100Ar_230601233756s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171225_B11100Ar_230601233811s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171226_B11100Ar_230601233822s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171227_B11100Ar_230601234016s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171228_B11100Ar_230601234152s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171229_B11100Ar_230601234227s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171230_B11100Ar_230601234230s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_171231_B11100Ar_230601234243s.nc4
# Reading ./data/OCO2_L2_Lite_FP.11.1r/oco2_LtCO2_180101_B11100Ar_230602001822s.nc4

# %%
# Now read the aggregated file
fid = netCDF4.Dataset(aggfile ,mode='r',format='NETCDF4')
plot_dic = {} #

for key in fid.variables.keys():
    plot_dic[key] = fid.variables[key][:].data
for group in fid.groups.keys() : # see if any data are in groups
    for key in fid.groups[group].variables.keys():
        plot_dic[group+'/'+key] =  fid.groups[group].variables[key][:].data # I'm not going any deeper than this for now.

# %%
# although we will plot all of the values set the limits based on the good data
ocogood = plot_dic['xco2_quality_flag'] == 0
lowerlimit = np.min(plot_dic['xco2'][ocogood])
upperlimit = np.max(plot_dic['xco2'][ocogood])

mapprojection = ccrs.PlateCarree()
fig = plt.figure()
ax = plt.axes(projection=mapprojection,label='allmap')
ax.coastlines()
gl=ax.gridlines(crs=mapprojection, draw_labels=True,linewidth=0.75, color='black')
ncolors=10
cmap=plt.cm.rainbow
bounds = np.linspace(lowerlimit,upperlimit,ncolors+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
c=plt.scatter(plot_dic['longitude'],plot_dic['latitude'],c=plot_dic['xco2'], cmap=cmap, norm=norm, edgecolor='black', linewidth=0)
plt.colorbar(ax=ax, orientation="vertical", pad=0.110, spacing='proportional', ticks=bounds, boundaries=bounds, format='%7.2f', extend = "both")
x=plt.plot([pointlon],[pointlat],marker='x',color='k',ms=15,mew=2)
ax.set_title(title_string)
# Out:
# Text(0.5, 1.0, 'Caltech')

# %%
#Now lets plot a time series of the data and overplot the good data in green.

#We can use Ticktock from spacepy to convert the TAI time in seconds since 1970-01-01 to a UTC datetime array.
t = Ticktock(plot_dic['time'][:], 'UNX')
oco2l2_utc = t.UTC

fig, ax = plt.subplots()
ax.plot_date(oco2l2_utc, plot_dic['xco2'],label='OCO-2 L2',color='k',marker='x')
ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2 Good',color='g',marker='o',ms=8)
ax.set_ylim([np.floor(lowerlimit)-5,np.ceil(upperlimit)+5])
ax.set_ylabel('xCO2 [ppm]')
ax.fmt_xdata = DateFormatter('%Y-%m-%d')
ax.grid(True)
fig.autofmt_xdate()
ax.set_title(title_string)
plt.legend()
# Out:
# /tmp/ipykernel_2167406/582496391.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc, plot_dic['xco2'],label='OCO-2 L2',color='k',marker='x')
# /tmp/ipykernel_2167406/582496391.py:9: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2 Land',color='g',marker='o',ms=8)

# %%
# Now lets compare the OCO-2 data with TCCON measurements.

# We can download and read the TCCON data for Caltech
url = "https://renc.osn.xsede.org/ini210004tommorrell/10.14291/tccon.ggg2020.pasadena01.R0/ci20120920_20240421.public.qc.nc"
download_file(url, './')

fidtccon = netCDF4.Dataset(os.path.basename(url) ,mode='r',format='NETCDF4')

# %%
fidtccon.variables.keys()
# Out:
# dict_keys(['time', 'prior_time', 'prior_altitude', 'ak_altitude', 'ak_pressure', 'ak_xco2', 'extrapolation_flags_ak_xco2', 'ak_xwco2', 'extrapolation_flags_ak_xwco2', 'ak_xlco2', 'extrapolation_flags_ak_xlco2', 'ak_xch4', 'extrapolation_flags_ak_xch4', 'ak_xhf', 'extrapolation_flags_ak_xhf', 'ak_xo2', 'extrapolation_flags_ak_xo2', 'ak_xn2o', 'extrapolation_flags_ak_xn2o', 'ak_xco', 'extrapolation_flags_ak_xco', 'ak_xh2o', 'extrapolation_flags_ak_xh2o', 'prior_temperature', 'prior_pressure', 'prior_density', 'prior_h2o', 'prior_co2', 'prior_n2o', 'prior_co', 'prior_ch4', 'prior_o2', 'prior_hf', 'prior_hdo', 'prior_gravity', 'prior_equivalent_latitude', 'prior_tropopause_altitude', 'prior_effective_latitude', 'prior_mid_tropospheric_potential_temperature', 'gfit_version', 'gsetup_version', 'year', 'day', 'hour', 'lat', 'long', 'zobs', 'zmin', 'solzen', 'azim', 'tout', 'pout', 'hout', 'sia', 'fvsi', 'wspd', 'wdir', 'xluft', 'xluft_error', 'xhf', 'xhf_error', 'xh2o', 'xh2o_error', 'xhdo', 'xhdo_error', 'xco', 'xco_error', 'xn2o', 'xn2o_error', 'xch4', 'xch4_error', 'xlco2_experimental', 'xlco2_error_experimental', 'xwco2_experimental', 'xwco2_error_experimental', 'xco2', 'xco2_error', 'ak_xhdo', 'extrapolation_flags_ak_xhdo', 'xco2_x2019', 'xco2_error_x2019', 'xwco2_experimental_x2019', 'xwco2_error_experimental_x2019', 'xlco2_experimental_x2019', 'xlco2_error_experimental_x2019', 'airmass', 'integration_operator', 'integration_operator_x2019', 'prior_xco2', 'prior_xch4', 'prior_xn2o', 'prior_xco', 'prior_xhf', 'prior_xh2o', 'prior_xhdo', 'prior_xco2_x2019'])

# %%
# Ticktock can also convert the TCCON time can also be converted to a UTC datetime array
t = Ticktock(fidtccon.variables['time'][:], 'UNX')
tccon_utc = t.UTC

# %%
fig, ax = plt.subplots()
ax.plot_date(tccon_utc, fidtccon.variables['xco2'][:],label='TCCON XCO2',color='k',marker='x')
ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2 Good',color='g',marker='o',ms=8)
ax.set_xlim([time_start,time_end])
ax.set_ylim([np.floor(lowerlimit)-5,np.ceil(upperlimit)+5])
ax.set_ylabel('xCO2 [ppm]')
ax.fmt_xdata = DateFormatter('%Y-%m-%d')
ax.grid(True)
fig.autofmt_xdate()
ax.set_title(title_string)
plt.legend()
# Out:
# /tmp/ipykernel_2167406/1965923777.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(tccon_utc, fidtccon.variables['xco2'][:],label='TCCON XCO2',color='k',marker='x')
# /tmp/ipykernel_2167406/1965923777.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(oco2l2_utc[ocogood], plot_dic['xco2'][ocogood],label='OCO-2 L2 Good',color='g',marker='o',ms=8)
